# %%
import torch
from transformers import pipeline
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import torch  # For tensor computations and running BERT
import requests  # For fetching news articles via API
import pandas as pd  # For organizing and analyzing article data
from transformers import pipeline  # For summarization and sentiment analysis
from sentence_transformers import SentenceTransformer  # For BERT-based embeddings
from sklearn.cluster import KMeans  # For topic modeling using clustering


# Load models
summarizer = pipeline("summarization", model="sshleifer/distilbart-cnn-12-6")
sentiment_analyzer = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# Summarization Function
def summarize_article(content):
    if len(content.split()) < 50:  # If the content is short, return as is
        return content
    summary = summarizer(content, max_length=60, min_length=25, do_sample=False)
    return summary[0]['summary_text']

# Sentiment Analysis Function
def analyze_sentiment(content):
    sentiment = sentiment_analyzer(content)
    label = sentiment[0]['label']  # e.g. '3 stars'
    return int(label.split()[0])   # convert '3 stars' → 3 (integer)

# Topic Modeling Function
def extract_topics(contents):
    embeddings = embedding_model.encode(contents)
    num_samples = len(contents)

    # Dynamically adjust the number of clusters
    num_clusters = min(5, num_samples)  # Choose the lesser of 5 or the number of articles

    if num_clusters <= 1:
        return {0: contents}  # Return all contents under one topic if we have only one article

    clustering_model = KMeans(n_clusters=num_clusters)
    clustering_model.fit(embeddings)
    cluster_labels = clustering_model.labels_

    topics = {i: [] for i in range(num_clusters)}
    for i, label in enumerate(cluster_labels):
        topics[label].append(contents[i])
    return topics
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Device set to use cpu
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import requests
from datetime import datetime, timedelta

def fetch_location_news(api_key, location, days_back=30):
    BASE_URL = "https://api.thenewsapi.com/v1/news/all"
    start_date = (datetime.utcnow() - timedelta(days=days_back)).strftime("%Y-%m-%d")
    all_articles = []
    page = 1

    while True:
        params = {
            "api_token": api_key,
            "language": "en",
            "search": location,
            "limit": 100,           # max per page
            "page": page,
            "published_after": start_date
        }

        response = requests.get(BASE_URL, params=params)
        print(f"Fetching page {page}... status: {response.status_code}")
        if response.status_code != 200:
            print(f"Error: {response.text}")
            break

        data = response.json().get("data", [])
        if not data:
            print("No more articles found.")
            break

        filtered_data = [
            article for article in data
            if article.get("relevance_score") is not None and article["relevance_score"] > 5
        ]

        all_articles.extend(filtered_data)
        page += 1

    print(f"Fetched {len(all_articles)} relevant articles about '{location}' since {start_date}")
    return all_articles

# %%
api_key = "Vjt328mOBEGo2AVyLJo3FIlpvvt3FLtkI16vIj4X"
arizona_articles = fetch_location_news(api_key, location="Arizona")

# Preview the results
for article in arizona_articles[:5]:
    print(f"[{article['published_at']}] {article['title']} ({article['source']})")
    print(article['url'])
    print("-" * 60)
# Out:
# Fetching page 1... status: 200
# Fetching page 2... status: 200
# Fetching page 3... status: 200
# Fetching page 4... status: 200
# Fetching page 5... status: 200
# Fetching page 6... status: 200
# Fetching page 7... status: 200
# Fetching page 8... status: 200
# Fetching page 9... status: 200
# Fetching page 10... status: 200
# Fetching page 11... status: 200
# Fetching page 12... status: 200
# Fetching page 13... status: 200
# Fetching page 14... status: 200
# Fetching page 15... status: 200
# Fetching page 16... status: 200
# Fetching page 17... status: 200
# Fetching page 18... status: 200
# Fetching page 19... status: 200
# Fetching page 20... status: 200
# Fetching page 21... status: 200
# Fetching page 22... status: 200
# Fetching page 23... status: 200
# Fetching page 24... status: 200
# Fetching page 25... status: 200
# Fetching page 26... status: 200
# Fetching page 27... status: 200
# Fetching page 28... status: 200
# Fetching page 29... status: 200
# Fetching page 30... status: 200
# Fetching page 31... status: 200
# Fetching page 32... status: 200
# Fetching page 33... status: 200
# Fetching page 34... status: 200
# Fetching page 35... status: 200
# Fetching page 36... status: 200
# Fetching page 37... status: 200
# Fetching page 38... status: 200
# Fetching page 39... status: 200
# Fetching page 40... status: 200
# Fetching page 41... status: 200
# Fetching page 42... status: 200
# Fetching page 43... status: 200
# Fetching page 44... status: 200
# Fetching page 45... status: 200
# Fetching page 46... status: 200
# Fetching page 47... status: 200
# Fetching page 48... status: 200
# Fetching page 49... status: 200
# Fetching page 50... status: 200
# Fetching page 51... status: 200
# Fetching page 52... status: 200
# Fetching page 53... status: 200
# Fetching page 54... status: 200
# Fetching page 55... status: 200
# Fetching page 56... status: 200
# Fetching page 57... status: 200
# Fetching page 58... status: 200
# Fetching page 59... status: 200
# Fetching page 60... status: 200
# Fetching page 61... status: 200
# Fetching page 62... status: 200
# Fetching page 63... status: 200
# Fetching page 64... status: 200
# Fetching page 65... status: 200
# Fetching page 66... status: 200
# Fetching page 67... status: 200
# Fetching page 68... status: 200
# Fetching page 69... status: 200
# Fetching page 70... status: 200
# Fetching page 71... status: 200
# Fetching page 72... status: 200
# Fetching page 73... status: 200
# Fetching page 74... status: 200
# Fetching page 75... status: 200
# Fetching page 76... status: 200
# Fetching page 77... status: 200
# Fetching page 78... status: 200
# Fetching page 79... status: 200
# Fetching page 80... status: 200
# Fetching page 81... status: 200
# Fetching page 82... status: 200
# Fetching page 83... status: 200
# Fetching page 84... status: 200
# Fetching page 85... status: 200
# Fetching page 86... status: 200
# Fetching page 87... status: 200
# Fetching page 88... status: 200
# Fetching page 89... status: 200
# Fetching page 90... status: 200
# Fetching page 91... status: 200
# Fetching page 92... status: 200
# Fetching page 93... status: 200
# Fetching page 94... status: 200
# Fetching page 95... status: 200
# Fetching page 96... status: 200
# Fetching page 97... status: 200
# Fetching page 98... status: 200
# Fetching page 99... status: 200
# Fetching page 100... status: 200
# Fetching page 101... status: 402
# Error: {"error":{"code":"usage_limit_reached","message":"The usage limit for this account has been reached."}}
# ✅ Fetched 300 articles about 'Arizona' since 2025-02-26
# [2025-03-22T12:34:16.000000Z] Ranking Arizona: Top 10 Italian restaurants in Arizona for 2025 (agriculture.einnews.com)
# https://azbigmedia.com/lifestyle/ranking-arizona-top-10-italian-restaurants-in-arizona-for-2025/
# ------------------------------------------------------------
# [2025-03-03T08:45:47.000000Z] Arizona State faces No. 22 Arizona after Sanon’s 28-point showing (winnipegfreepress.com)
# https://www.winnipegfreepress.com/uncategorized/2025/03/03/arizona-state-faces-no-22-arizona-after-sanons-28-point-showing
# ------------------------------------------------------------
# [2025-03-27T18:51:35.000000Z] Koa Peat Commits To Arizona (basketball.realgm.com)
# https://basketball.realgm.com/wiretap/279797/Koa-Peat-Commits-To-Arizona
# ------------------------------------------------------------
# [2025-03-05T06:36:09.000000Z] Henri Veesaar scores 22 points, No. 24 Arizona pulls away to beat rival Arizona State 113-100 (winnipegfreepress.com)
# https://www.winnipegfreepress.com/uncategorized/2025/03/05/henri-veesaar-scores-22-points-no-24-arizona-pulls-away-to-beat-rival-arizona-state-113-100
# ------------------------------------------------------------
# [2025-03-04T15:30:12.000000Z] Arizona vs. Arizona State odds, prediction, time: 2025 college basketball picks, March 4 bets by proven model (cbssports.com)
# https://www.cbssports.com/college-basketball/news/arizona-vs-arizona-state-odds-prediction-time-2025-college-basketball-picks-march-4-bets-by-proven-model/
# ------------------------------------------------------------

# %%
arizona_articles
# Out:
# [{'uuid': 'fbbba121-2dd1-4584-b62e-351e9adc07ce',
#   'title': 'Ranking Arizona: Top 10 Italian restaurants in Arizona for 2025',
#   'description': 'Here are the Top 10\xa0Italian restaurants in Arizona, based on public voting for the 2025 edition of Ranking Arizona.',
#   'keywords': '',
#   'snippet': 'Featured\n\nHere are the Top 10 Italian restaurants in Arizona, based on public voting for the 2025 edition of Ranking Arizona, the state’s biggest and most com...',
#   'url': 'https://azbigmedia.com/lifestyle/ranking-arizona-top-10-italian-restaurants-in-arizona-for-2025/',
#   'image_url': 'https://azbigmedia.com/wp-content/uploads/2025/03/Italian-restaurants-in-Arizona.png',
#   'language': 'en',
#   'published_at': '2025-03-22T12:34:16.000000Z',
#   'source': 'agriculture.einnews.com',
#   'categories': ['food'],
#   'relevance_score': 23.638367},
#  {'uuid': '151c305c-5f03-47a0-a727-fa4f2f84ed03',
#   'title': 'Arizona State faces No. 22 Arizona after Sanon’s 28-point showing',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Arizona State Sun Devils (13-16, 4-14 Big 12) at Arizona Wildcats (19-10, 13-6 Big 12)\n\nTucson, Arizona; Tuesday, 11 p.m. EST\n\nBOTTOM LINE: Arizona State visits...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/03/arizona-state-faces-no-22-arizona-after-sanons-28-point-showing',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-03T08:45:47.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 23.514057},
#  {'uuid': '2796ef6b-c437-4175-8962-ae8a58fa9e69',
#   'title': 'Koa Peat Commits To Arizona',
#   'description': 'Koa Peat Commits To Arizona - RealGM Wiretap',
#   'keywords': 'Koa Peat Commits To Arizona, RealGM Wiretap',
#   'snippet': 'Koa Peat, one of the highest-ranked uncommitted high school prospects in the country, has committed to Arizona. Peat chose Arizona over Arizona State, Baylor, H...',
#   'url': 'https://basketball.realgm.com/wiretap/279797/Koa-Peat-Commits-To-Arizona',
#   'image_url': 'https://basketball.realgm.com/images/nba/4.2/wiretap/photos/2006/Logo_Arizona.jpg',
#   'language': 'en',
#   'published_at': '2025-03-27T18:51:35.000000Z',
#   'source': 'basketball.realgm.com',
#   'categories': ['sports'],
#   'relevance_score': 22.2285},
#  {'uuid': '7e51495f-0848-4b95-b1fa-93dc547fc764',
#   'title': 'Henri Veesaar scores 22 points, No. 24 Arizona pulls away to beat rival Arizona State 113-100',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'TUCSON, Ariz. (AP) — Henri Veesaar scored 22 points, Caleb Love added 21 and No. 24 Arizona pulled away for a 113-100 win over rival Arizona State on Tuesday ...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/05/henri-veesaar-scores-22-points-no-24-arizona-pulls-away-to-beat-rival-arizona-state-113-100',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2025/02/791f3d49ed85625c384c12eaa1c811e0d793cbdfab4b75c88a52e76e90e89f34.jpg',
#   'language': 'en',
#   'published_at': '2025-03-05T06:36:09.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': [],
#   'relevance_score': 22.208956},
#  {'uuid': 'ab77d17a-1ba1-4d74-8d94-ba3e5ef5a769',
#   'title': 'Arizona vs. Arizona State odds, prediction, time: 2025 college basketball picks, March 4 bets by proven model',
#   'description': "SportsLine's model just revealed its college basketball picks for Arizona State Sun Devils vs. Arizona Wildcats on Tuesday night",
#   'keywords': '',
#   'snippet': "The No. 24 Arizona Wildcats look to clinch a top-four seed in next week's Big 12 Tournament as they host in-state rivals, the Arizona State Sun Devils on Tuesda...",
#   'url': 'https://www.cbssports.com/college-basketball/news/arizona-vs-arizona-state-odds-prediction-time-2025-college-basketball-picks-march-4-bets-by-proven-model/',
#   'image_url': 'https://sportshub.cbsistatic.com/i/r/2025/02/01/71b76b32-ee7d-42db-9719-9197e8592f41/thumbnail/1200x675/cff366c7f5ee17634c230a7b8dc6a9c2/caleb-love-arizona-wildcats-usatsi.jpg',
#   'language': 'en',
#   'published_at': '2025-03-04T15:30:12.000000Z',
#   'source': 'cbssports.com',
#   'categories': ['sports'],
#   'relevance_score': 22.01765},
#  {'uuid': 'ddd4f4e2-ad05-4b28-8815-ee884db76639',
#   'title': 'HATE IN ARIZONA: Arsonist Targets Jewish Community Center in Arizona, Suspect Arrested',
#   'description': 'HATE IN ARIZONA: An arsonist allegedly set fire to the Khal Chasidim Jewish Community Center in Casa Grande, Arizona, causing extensive damage to the newly reno...',
#   'keywords': '',
#   'snippet': 'HATE IN ARIZONA: An arsonist allegedly set fire to the Khal Chasidim Jewish Community Center in Casa Grande, Arizona, causing extensive damage to the newly reno...',
#   'url': 'https://www.theyeshivaworld.com/news/liveblogs/live-blog/2373474/hate-in-arizone-arsonist-targets-jewish-community-center-in-arizona-suspect-arrested.html',
#   'image_url': 'https://yeshivaworld.b-cdn.net/wp-content/uploads/2025/03/IMG-20250307-WA0184-768x576.jpg',
#   'language': 'en',
#   'published_at': '2025-03-09T01:27:51.000000Z',
#   'source': 'theyeshivaworld.com',
#   'categories': ['general'],
#   'relevance_score': 21.819431},
#  {'uuid': '524d9443-5939-42d0-91fd-9f8f237122ff',
#   'title': 'Mayo plans $1.9B expansion in Arizona',
#   'description': '"Mayo Clinic announces $1.9B investment in Arizona, expanding its Phoenix campus with new buildings, advanced technology, and enhanced patient experience as par',
#   'keywords': '',
#   'snippet': "Rochester, Minn.-based Mayo Clinic is investing nearly $1.9 billion to expand its Phoenix campus, marking the health system's largest investment in the state.\n\n...",
#   'url': 'https://www.beckershospitalreview.com/capital/mayo-plans-1-9b-expansion-in-arizona.html',
#   'image_url': 'https://www.beckershospitalreview.com/templates/beckers/assets/images/bhr-new-logo.png',
#   'language': 'en',
#   'published_at': '2025-03-03T16:15:25.000000Z',
#   'source': 'beckershospitalreview.com',
#   'categories': ['health'],
#   'relevance_score': 21.286545},
#  {'uuid': 'ad71d7c8-63c6-423b-a9d3-ae3d95584ab4',
#   'title': "Tucson's Landmark Resort, Arizona Inn, Listed for Sale",
#   'description': "Article - Tucson's Landmark Resort, Arizona Inn, Listed for Sale - The resort has been owned and operated by the family of its founder since its inception in 19...",
#   'keywords': '',
#   'snippet': 'Image Credit Arizona Inn\n\nThe historic Arizona Inn, located in Tucson, Arizona, is up for sale.\n\nThe resort has been owned and operated by the family of its fou...',
#   'url': 'https://www.hotelnewsresource.com/article135790.html',
#   'image_url': 'https://www.hotelnewsresource.com/theme/Nevistas2/images/icon.png',
#   'language': 'en',
#   'published_at': '2025-03-27T16:48:59.000000Z',
#   'source': 'hotelnewsresource.com',
#   'categories': ['travel'],
#   'relevance_score': 21.150055},
#  {'uuid': '86453131-826e-4b85-9853-0df16d026a50',
#   'title': 'Northern Arizona hosts Hawthorne and Northern Colorado',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Northern Colorado Bears (21-8, 13-3 Big Sky) at Northern Arizona Lumberjacks (16-13, 7-9 Big Sky)\n\nFlagstaff, Arizona; Saturday, 10 p.m. EST\n\nBOTTOM LINE: North...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/02/28/northern-arizona-hosts-hawthorne-and-northern-colorado',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-02-28T08:48:53.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': [],
#   'relevance_score': 21.12038},
#  {'uuid': '06b04c9e-dcbb-4695-b064-29067e53affc',
#   'title': 'Northern Arizona hosts Hawthorne and Northern Colorado',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Northern Colorado Bears (21-8, 13-3 Big Sky) at Northern Arizona Lumberjacks (16-13, 7-9 Big Sky)\n\nFlagstaff, Arizona; Saturday, 10 p.m. EST\n\nBETMGM SPORTSBOOK ...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/01/northern-arizona-hosts-hawthorne-and-northern-colorado-2',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-01T08:50:23.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 21.070208},
#  {'uuid': '36d06543-6a6b-492c-97c4-0af73ee77c8a',
#   'title': 'Spin Master Releases New AriZona Iced Tea Party Game',
#   'description': 'Spin Master has released a new party game with an famous drink, as AriZona 99 – The Official AriZona Iced Tea Party Game is out now',
#   'keywords': '',
#   'snippet': 'Posted in: Card Games, Games, Spin Master Games, Tabletop | Tagged: AriZona 99, AriZona Iced Tea\n\nSpin Master Releases New AriZona Iced Tea Party Game\n\nSpin Mas...',
#   'url': 'https://bleedingcool.com/games/spin-master-releases-new-arizona-iced-tea-party-game/',
#   'image_url': 'https://bleedingcool.com/wp-content/uploads/2025/03/Arizona-99-–-The-Official-Arizona-Iced-Tea-Party-Game-2000x1125.jpg',
#   'language': 'en',
#   'published_at': '2025-03-10T23:47:08.000000Z',
#   'source': 'bleedingcool.com',
#   'categories': ['entertainment'],
#   'relevance_score': 21.03053},
#  {'uuid': 'fb0c297c-14b9-44ea-b249-dcc0686e09c6',
#   'title': 'Top-10 recruit Koa Peat picks Arizona',
#   'description': 'Saying he wanted to be pushed at his new school, Koa Peat, one of the highest-ranked uncommitted high school prospects in the country, has chosen to play at Ari...',
#   'keywords': '',
#   'snippet': 'Open Extended Reactions\n\nTop-10 senior Koa Peat, one of the highest-ranked uncommitted high school prospects in the country, has committed to Arizona.\n\nPeat mad...',
#   'url': 'https://www.espn.com/mens-college-basketball/story/_/id/44430043/top-10-recruit-koa-peat-picks-arizona-all-want-do-win',
#   'image_url': 'https://a4.espncdn.com/combiner/i?img=%2Fphoto%2F2022%2F0722%2Fr1039419_1296x729_16%2D9.jpg',
#   'language': 'en',
#   'published_at': '2025-03-27T17:47:18.000000Z',
#   'source': 'espn.com',
#   'categories': ['sports', 'general'],
#   'relevance_score': 20.840277},
#  {'uuid': '451ac5c6-d4a2-43cf-9971-31a6c3d3bbec',
#   'title': 'Original Arizona Sunshine Ends Multiplayer Support This July',
#   'description': "The original Arizona Sunshine is ending support for its online multiplayer this July, citing Unity's discontinuation of the UNET Service.",
#   'keywords': '',
#   'snippet': "The original Arizona Sunshine is ending support for its online multiplayer this July, citing Unity's discontinuation of the UNet Service.\n\nOne of modern VR's ol...",
#   'url': 'https://www.uploadvr.com/original-arizona-sunshine-ends-multiplayer-support-this-july/',
#   'image_url': 'https://www.uploadvr.com/content/images/2025/03/unnamed.jpg',
#   'language': 'en',
#   'published_at': '2025-03-14T23:00:27.000000Z',
#   'source': 'uploadvr.com',
#   'categories': ['tech'],
#   'relevance_score': 20.830921},
#  {'uuid': 'f85bb476-6924-4df1-9203-959d9c239f7d',
#   'title': 'Duke meets Arizona in Sweet 16 matchup',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Arizona Wildcats (24-12, 16-8 Big 12) vs. Duke Blue Devils (33-3, 22-1 ACC)\n\nNewark, New Jersey; Thursday, 9:39 p.m. EDT\n\nBETMGM SPORTSBOOK LINE: Blue Devils -9...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/27/duke-meets-arizona-in-sweet-16-matchup',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-27T07:44:53.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': [],
#   'relevance_score': 20.693325},
#  {'uuid': 'd0c686f9-0f51-4e8e-b12b-f73becede318',
#   'title': 'Queens, Northern Arizona square off in CBI Tournament',
#   'description': 'The Queens Royals square off against the Northern Arizona Lumberjacks in the College Basketball Invitational',
#   'keywords': "Basketball, Men's college basketball, College basketball, College sports, Sports, Article, 120051567",
#   'snippet': 'The Queens Royals square off against the Northern Arizona Lumberjacks in the College Basketball Invitational\n\nBy The Associated Press\n\nNorthern Arizona Lumberja...',
#   'url': 'https://abcnews.go.com/Sports/wireStory/queens-northern-arizona-square-off-cbi-tournament-120051567',
#   'image_url': 'https://s.abcnews.com/images/US/abc_news_default_2000x2000_update_16x9_992.jpg',
#   'language': 'en',
#   'published_at': '2025-03-22T07:57:54.000000Z',
#   'source': 'abcnews.go.com',
#   'categories': ['sports', 'general'],
#   'relevance_score': 20.679827},
#  {'uuid': 'ef8e7540-e294-45c5-8df4-ed489a78b4b2',
#   'title': 'Report: Arizona State makes decision on Bobby Hurley',
#   'description': 'Arizona State has reportedly made a decision regarding the future of Bobby Hurley and may bring him back for another season as head coach.',
#   'keywords': '',
#   'snippet': 'Arizona State has reportedly made a decision regarding the future of Bobby Hurley.\n\nThe Sun Devils will bring back Hurley for next season despite the team’s s...',
#   'url': 'https://larrybrownsports.com/college-basketball/arizona-state-bobby-hurley-remain-coach/686140',
#   'image_url': 'https://larrybrownsports.com/wp-content/uploads/2025/02/bobby-hurley-1.jpg',
#   'language': 'en',
#   'published_at': '2025-03-11T23:16:28.000000Z',
#   'source': 'larrybrownsports.com',
#   'categories': ['sports'],
#   'relevance_score': 20.679827},
#  {'uuid': '79e8f446-c36b-4877-8620-42f9f6304e08',
#   'title': 'Protect Parental Rights & Informed Consent In Arizona',
#   'description': '🖨️ Print post Arizona lawmakers have introduced a crucial bill that ensures parents are fully informed of their right to obtain vaccine exemptions for scho...',
#   'keywords': '',
#   'snippet': 'Arizona lawmakers have introduced a crucial bill that ensures parents are fully informed of their right to obtain vaccine exemptions for school attendance.\n\nHB ...',
#   'url': 'https://www.westonaprice.org/protect-parental-rights-informed-consent-in-arizona/',
#   'image_url': 'https://www.westonaprice.org/wp-content/uploads/act-now.png',
#   'language': 'en',
#   'published_at': '2025-03-05T16:17:37.000000Z',
#   'source': 'westonaprice.org',
#   'categories': ['health', 'food'],
#   'relevance_score': 20.678658},
#  {'uuid': 'f900cacb-06b8-4005-b3b9-96adf19be56f',
#   'title': 'Mason leads Arizona State against No. 9 Texas Tech',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Texas Tech Red Raiders (23-7, 14-5 Big 12) at Arizona State Sun Devils (13-17, 4-15 Big 12)\n\nTempe, Arizona; Saturday, 8 p.m. EST\n\nBETMGM SPORTSBOOK LINE: Red R...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/08/mason-leads-arizona-state-against-no-9-texas-tech',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-08T08:48:53.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 20.667282},
#  {'uuid': '165416ae-6bf8-4220-b95d-b0833c506c99',
#   'title': '10 Best Movies Set In Arizona, Ranked',
#   'description': "The Cooper State's stunning deserts have been the setting for many Hollywood films, from westerns to comedies and more. Here are the best movies set in Arizona.",
#   'keywords': '',
#   'snippet': 'Depending on who you ask, Arizona is known as The Grand Canyon State and The Copper State. But if you ask us, it should also be called The Grand Cinema State or...',
#   'url': 'https://www.slashfilm.com/1799396/best-movies-set-in-arizona-ranked/',
#   'image_url': 'https://www.slashfilm.com/img/gallery/10-best-movies-set-in-arizona-ranked/l-intro-1740506112.jpg',
#   'language': 'en',
#   'published_at': '2025-03-03T13:15:01.000000Z',
#   'source': 'slashfilm.com',
#   'categories': ['entertainment'],
#   'relevance_score': 20.636648},
#  {'uuid': '8b1dcec1-60c2-400f-b417-ae4a38372c3d',
#   'title': "Arizona State fires women's basketball coach Natasha Adair",
#   'description': "Arizona State has fired women's basketball coach Natasha Adair after three seasons of not making the NCAA tournament.",
#   'keywords': '',
#   'snippet': "Open Extended Reactions\n\nTEMPE, Ariz. -- Arizona State fired women's basketball coach Natasha Adair on Saturday after three seasons of not making the NCAA tourn...",
#   'url': 'https://www.espn.com/womens-college-basketball/story/_/id/44164223/arizona-state-fires-women-basketball-coach-natasha-adair',
#   'image_url': 'https://a2.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0308%2Fr1461230_1296x729_16%2D9.jpg',
#   'language': 'en',
#   'published_at': '2025-03-08T16:10:48.000000Z',
#   'source': 'espn.com',
#   'categories': ['sports', 'general'],
#   'relevance_score': 20.530085},
#  {'uuid': '715d7d02-0257-46a8-9c73-15ad15e702d8',
#   'title': 'Arizona executes first death row inmate since 2022',
#   'description': "Arizona has executed a 53-year-old man convicted of kidnapping and murdering his girlfriend's former partner in 2002, marking the first death by the state since...",
#   'keywords': 'Top Stories, U.S., Law and Crime, Supreme Court, Prince',
#   'snippet': "March 20 (UPI) -- Arizona has executed a 53-year-old man convicted of kidnapping and murdering his girlfriend's former partner in 2002, marking the first death ...",
#   'url': 'https://www.upi.com/Top_News/US/2025/03/20/Arizona-execution/9131742454887/',
#   'image_url': 'https://cdnph.upi.com/ph/st/th/9131742454887/2025/upi_com/69e2ae6231bc2963320433fed3258280/v1.5/Arizona-executes-first-death-row-inmate-since-2022.jpg?lg=5',
#   'language': 'en',
#   'published_at': '2025-03-20T09:10:12.000000Z',
#   'source': 'upi.com',
#   'categories': ['general'],
#   'relevance_score': 20.32574},
#  {'uuid': '31e87cfd-7c03-4b15-a112-0afea05d0ec3',
#   'title': 'India-origin Arizona Senator nominated for rising star award',
#   'description': 'HOUSTON, Mar 20: Indian-origin Arizona State Senator Priya Sundareshan has been nominated for the prestigious Gabrielle Giffords Rising Star Award by EMILYs Lis...',
#   'keywords': '',
#   'snippet': 'HOUSTON, Mar 20: Indian-origin Arizona State Senator Priya Sundareshan has been nominated for the prestigious Gabrielle Giffords Rising Star Award by EMILYs Lis...',
#   'url': 'https://www.dailyexcelsior.com/india-origin-arizona-senator-nominated-for-rising-star-award/',
#   'image_url': 'https://cdndailyexcelsior.b-cdn.net/wp-content/uploads/2025/03/Award-1.jpg',
#   'language': 'en',
#   'published_at': '2025-03-20T08:18:56.000000Z',
#   'source': 'dailyexcelsior.com',
#   'categories': ['general'],
#   'relevance_score': 20.28769},
#  {'uuid': 'd1fea8a9-6c2a-42c0-bc60-1d795a58e971',
#   'title': 'Gophers get commitment from Arizona wide receiver Rico Blassingame',
#   'description': 'Blassingame, a 6-3, 180-pounder, has 15 offers from Power Four schools.',
#   'keywords': '',
#   'snippet': 'Blassingame, 6-3 and 180 pounds, is the 12th-ranked player in Arizona in the 2026 class and the 142nd-ranked wide receiver nationally in the 247Sports.com compo...',
#   'url': 'https://www.startribune.com/gophers-football-commitment-rico-blassingame-wide-receiver-tolleson-arizona/601240541',
#   'image_url': 'https://arc.stimg.co/startribunemedia/YIWHO47MFBFP5OW7WFYIPETZ7Y.JPG?&w=1200&ar=1.91:1&fit=crop',
#   'language': 'en',
#   'published_at': '2025-03-21T01:17:51.000000Z',
#   'source': 'startribune.com',
#   'categories': ['sports', 'general'],
#   'relevance_score': 20.2647},
#  {'uuid': 'b06901b0-bd37-4adf-8a91-972009f03acc',
#   'title': '2025 MLB Season Preview: Arizona Diamondbacks',
#   'description': 'Now two years removed from their NL Pennant, can the DBacks make a similar run in 2025?',
#   'keywords': '',
#   'snippet': 'Entering the 2025 season, it’s hard to tell what’s more surprising—the fact that it’s only been two years since the Arizona Diamondbacks were in the Wor...',
#   'url': 'https://www.pinstripealley.com/2025/3/25/24393405/2025-mlb-season-preview-arizona-diamondbacks-corbin-burnes-zac-gallen-corbin-carroll-ketel-marte',
#   'image_url': 'https://cdn.vox-cdn.com/thumbor/MWHLAejEiftAr12HdsUITKJFxGg=/0x0:4328x2266/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/25925751/2175523110.jpg',
#   'language': 'en',
#   'published_at': '2025-03-25T12:53:21.000000Z',
#   'source': 'pinstripealley.com',
#   'categories': ['sports'],
#   'relevance_score': 20.253445},
#  {'uuid': '4101013e-ee43-43fa-becf-1142fc019730',
#   'title': 'Arizona court rules abortion ban after 15 weeks of pregnancy unconstitutional',
#   'description': "Maricopa County Superior Court of Arizona ruled Wednesday that Arizona's abortion ban after 15 weeks of pregnancy was unconstitutional and permanently enjoined ...",
#   'keywords': '',
#   'snippet': 'Maricopa County Superior Court of Arizona ruled Wednesday that Arizona’s abortion ban after 15 weeks of pregnancy was unconstitutional and permanently enjoine...',
#   'url': 'https://www.jurist.org/news/2025/03/arizona-court-rules-abortion-ban-after-15-weeks-of-pregnancy-unconstitutional/',
#   'image_url': 'https://www.jurist.org/news/wp-content/uploads/sites/4/2024/06/Keep_abortion_legal_-_sign_-_Demonstration_in_front_of_SCOTUS_May_3_2022_848-1.jpg',
#   'language': 'en',
#   'published_at': '2025-03-07T10:15:48.000000Z',
#   'source': 'jurist.org',
#   'categories': ['general', 'politics'],
#   'relevance_score': 20.200584},
#  {'uuid': '4a6ef0c2-14eb-4249-8435-7b702a7e6d62',
#   'title': "Arizona Iced Tea Responds to Southwest Airlines' Baggage ...",
#   'description': "Arizona Iced Tea maintains its 99-cent price tag amidst Southwest Airlines' new baggage fees.",
#   'keywords': '',
#   'snippet': 'With Southwest Airlines introducing new fees, AriZona Iced Tea wants you to know they’re keeping their prices grounded.\n\nAfter 54 years, the airline announced...',
#   'url': 'https://www.complex.com/life/a/alex-ocho/arizona-iced-tea-shades-southwest-airlines-changing-checked-bag-policy',
#   'image_url': 'https://images.complex.com/complex/image/upload/ar_1.91,c_fill,g_auto,q_auto,w_1200/v1741723643/arizona_iced_tea_southwest_airlines_Baggage_check_in_naurpw',
#   'language': 'en',
#   'published_at': '2025-03-11T20:57:32.000000Z',
#   'source': 'complex.com',
#   'categories': ['entertainment'],
#   'relevance_score': 20.19238},
#  {'uuid': '19bc41f1-2193-4e33-a5b1-88b34084a710',
#   'title': 'Queens and Northern Arizona play in CBI Tournament matchup',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Northern Arizona Lumberjacks (18-15, 9-11 Big Sky) vs. Queens Royals (19-14, 12-8 ASUN)\n\nDaytona Beach, Florida; Sunday, 5 p.m. EDT\n\nBOTTOM LINE: Queens and Nor...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/23/queens-and-northern-arizona-play-in-cbi-tournament-matchup',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-23T07:44:46.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 20.054413},
#  {'uuid': 'f2a0c02b-886f-440e-8523-b0c1a3bc43f1',
#   'title': 'No. 24 Arizona visits Kansas following Veesaar’s 22-point performance',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Arizona Wildcats (20-10, 14-6 Big 12) at Kansas Jayhawks (19-11, 10-9 Big 12)\n\nLawrence, Kansas; Saturday, 4:30 p.m. EST\n\nBETMGM SPORTSBOOK LINE: Jayhawks -3.5;...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/08/no-24-arizona-visits-kansas-following-veesaars-22-point-performance',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-08T08:50:19.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': [],
#   'relevance_score': 20.032902},
#  {'uuid': 'f7136647-5e9d-4555-91f9-0aef8d078f37',
#   'title': 'Arizona Snowbowl Bans Idiotic Skier Following Viral TikTok Video',
#   'description': 'Earlier this month, a TikTok user shared a video of him getting into a few altercations with two guests at the Arizona Snowbowl.',
#   'keywords': '',
#   'snippet': 'Flagstaff, Arizona — This story is among the best examples of what happens when you act like an idiot on the slopes.\n\nEarlier this month, a TikTok user shared...',
#   'url': 'https://unofficialnetworks.com/2025/03/24/arizona-snowbowl-bans-idiot-skier/',
#   'image_url': 'https://unofficialnetworks.com/wp-content/uploads/2025/03/Screenshot-2025-03-22-at-7.56.46-PM.jpg',
#   'language': 'en',
#   'published_at': '2025-03-24T14:15:07.000000Z',
#   'source': 'unofficialnetworks.com',
#   'categories': ['sports'],
#   'relevance_score': 19.95435},
#  {'uuid': '9bc89592-e874-49e9-b032-4b3892e2529e',
#   'title': 'Montana plays in Big Sky Tournament against the Northern Arizona',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Northern Arizona Lumberjacks (18-14, 9-10 Big Sky) vs. Montana Grizzlies (22-9, 15-3 Big Sky)\n\nBoise, Idaho; Sunday, 10 p.m. EDT\n\nBOTTOM LINE: Montana plays in ...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/09/montana-plays-in-big-sky-tournament-against-the-northern-arizona',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-09T08:45:31.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 19.952051},
#  {'uuid': '6dbaf5e6-3c38-4c1b-a313-7d140f01c13e',
#   'title': 'Chicago Cubs to face the Arizona Diamondbacks two best starters',
#   'description': 'The Chicago Cubs will return to playing spring training games tomorrow after they return from their trip to Japan. The Cubs dropped both games in the Tokyo Seri...',
#   'keywords': '',
#   'snippet': 'The Chicago Cubs will return to playing spring training games tomorrow after they return from their trip to Japan.\n\nThe Cubs dropped both games in the Tokyo Ser...',
#   'url': 'https://www.yardbarker.com/mlb/articles/chicago_cubs_to_face_the_arizona_diamondbacks_two_best_starters/s1_17081_41934853',
#   'image_url': 'https://www.yardbarker.com/media/6/1/61a085820b137fb98a06b24dc85fb2ca5d90045f/thumb_16x9/USATSI_25563964-786x600.jpg',
#   'language': 'en',
#   'published_at': '2025-03-20T23:02:13.000000Z',
#   'source': 'yardbarker.com',
#   'categories': ['sports'],
#   'relevance_score': 19.929062},
#  {'uuid': 'f64d3376-34df-4d6f-81d1-24a8a91e44c8',
#   'title': 'Chicago Cubs: Arizona Diamondbacks reveal pitching matchups for opening series',
#   'description': 'The Chicago Cubs will return to playing spring training games tomorrow after they return from their trip to Japan. The Cubs dropped both games in the Tokyo Seri...',
#   'keywords': '',
#   'snippet': 'The Chicago Cubs will return to playing spring training games tomorrow after they return from their trip to Japan.\n\nThe Cubs dropped both games in the Tokyo Ser...',
#   'url': 'https://www.yardbarker.com/mlb/articles/chicago_cubs_arizona_diamondbacks_reveal_pitching_matchups_for_opening_series/s1_17081_41934853',
#   'image_url': 'https://www.yardbarker.com/media/6/1/61a085820b137fb98a06b24dc85fb2ca5d90045f/thumb_16x9/USATSI_25563964-786x600.jpg',
#   'language': 'en',
#   'published_at': '2025-03-20T23:02:13.000000Z',
#   'source': 'yardbarker.com',
#   'categories': ['sports'],
#   'relevance_score': 19.929062},
#  {'uuid': '2f623807-2ca2-4631-b323-22cd5c6b461a',
#   'title': 'Houston vs. Arizona odds, prediction: BetMGM Sportsbook bonus code POSTBET',
#   'description': 'Get in on the action with BetMGM Sportsbook bonus code POSTBET and get up to $1,500 back in bonus bets if your first bet doesn’t win.',
#   'keywords': 'Betting, Sports, College Basketball, arizona wildcats, betting promos, college basketball betting, houston cougars, march madness, march madness 2025, sports betting, Sports Picks',
#   'snippet': 'Gambling content 21+. The New York Post may receive an affiliate commission if you sign up through our links. Read our editorial standards for more information....',
#   'url': 'https://nypost.com/2025/03/15/betting/houston-vs-arizona-odds-prediction-betmgm-sportsbook-bonus-code-postbet/',
#   'image_url': 'https://nypost.com/wp-content/uploads/sites/2/2025/03/2204958220.jpg?quality=75&strip=all&w=1024',
#   'language': 'en',
#   'published_at': '2025-03-15T19:02:43.000000Z',
#   'source': 'nypost.com',
#   'categories': ['general'],
#   'relevance_score': 19.872478},
#  {'uuid': 'a2985788-6285-4e5f-8a16-4516ee6ab8bf',
#   'title': 'Arizona and Oregon play in second round of NCAA Tournament',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Oregon Ducks (25-9, 13-9 Big Ten) vs. Arizona Wildcats (23-12, 16-8 Big 12)\n\nSeattle; Sunday, 9:40 p.m. EDT\n\nBETMGM SPORTSBOOK LINE: Wildcats -3.5; over/under i...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/23/arizona-and-oregon-play-in-second-round-of-ncaa-tournament',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-23T07:44:43.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 19.776152},
#  {'uuid': '30510d1e-e287-4277-a51e-7b0d1b749acf',
#   'title': 'Arizona laws ordering citizenship proof struck down by appeals court',
#   'description': 'A federal appeals court struck down provisions in two Arizona voting laws that sought to increase proof-of-citizenship requirements for voter registration.',
#   'keywords': '',
#   'snippet': 'A federal appeals court struck down provisions in two Arizona voting laws that sought to increase proof-of-citizenship requirements for voter registration, sayi...',
#   'url': 'https://www.nbcnews.com/news/latino/arizona-laws-ordering-citizenship-proof-struck-appeals-court-rcna194105',
#   'image_url': 'https://media-cldnry.s-nbcnews.com/image/upload/t_nbcnews-fp-1200-630,f_auto,q_auto:best/rockcms/2025-02/250227-Voting-AZ-aa-451-cd04f4.jpg',
#   'language': 'en',
#   'published_at': '2025-02-27T22:16:55.000000Z',
#   'source': 'nbcnews.com',
#   'categories': ['politics', 'general'],
#   'relevance_score': 19.727625},
#  {'uuid': 'd0448d3a-8be7-4a64-851f-305770a466ee',
#   'title': 'Arizona executes man by lethal injection for 2002 murder',
#   'description': "Aaron Gunches, who had dropped legal efforts to halt his execution, was sentenced to death for the 2002 murder of Ted Price, his girlfriend's ex-husband.",
#   'keywords': 'Oklahoma, Execution',
#   'snippet': 'A 53-year-old man convicted of murder was put to death by lethal injection in Arizona on Wednesday in the first execution in the southwestern U.S. state in more...',
#   'url': 'https://www.cbsnews.com/news/arizona-executes-aaron-gunches-by-lethal-injection-for-2002-murder/',
#   'image_url': 'https://assets2.cbsnewsstatic.com/hub/i/r/2019/04/04/c1851a66-73f5-425a-be5d-0f9a04538305/thumbnail/1200x630g8/0b137c3873e21d39c8939d72cde1d679/texas-execution-chamber-51543324.jpg?v=765ef194a4bf4701e45ec9d5712af42f',
#   'language': 'en',
#   'published_at': '2025-03-19T20:51:36.000000Z',
#   'source': 'cbsnews.com',
#   'categories': [],
#   'relevance_score': 19.722652},
#  {'uuid': '2dc67869-5ca5-4f74-9287-1d4f25b51177',
#   'title': 'Report: Arizona State expected to bring back Bobby Hurley',
#   'description': 'Arizona State coach Bobby Hurley is expected to return for his 11th season, a source told the Associated Press, confirming a report that was released on Tuesday...',
#   'keywords': '',
#   'snippet': 'Open Extended Reactions\n\nTEMPE, Ariz. -- Arizona State coach Bobby Hurley is expected to return for his 11th season, a source told the Associated Press, confirm...',
#   'url': 'https://www.espn.com/mens-college-basketball/story/_/id/44212120/arizona-state-expected-bring-back-bobby-hurley',
#   'image_url': 'https://a2.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0311%2Fr1462811_1296x729_16%2D9.jpg',
#   'language': 'en',
#   'published_at': '2025-03-12T00:58:54.000000Z',
#   'source': 'espn.com',
#   'categories': ['sports'],
#   'relevance_score': 19.722652},
#  {'uuid': '97cfe66c-2efd-42ca-a430-df06e6aa5241',
#   'title': 'The Ensign Group Continues Growth in Arizona',
#   'description': 'SAN JUAN CAPISTRANO, Calif., March  03, 2025  (GLOBE NEWSWIRE) -- The Ensign Group, Inc. ( ENSG), the parent company of the EnsignTM group of companies, which i',
#   'keywords': 'GuruFocus, Article, News, Marketwired, ENSG',
#   'snippet': 'SAN JUAN CAPISTRANO, Calif., March 03, 2025 (GLOBE NEWSWIRE) -- The Ensign Group, Inc. ( ENSG), the parent company of the EnsignTM group of companies, which inv...',
#   'url': 'https://www.gurufocus.com/news/2725330/the-ensign-group-continues-growth-in-arizona',
#   'image_url': 'https://static.gurufocus.com/images/global_logo_twitter_card.png',
#   'language': 'en',
#   'published_at': '2025-03-03T22:00:02.000000Z',
#   'source': 'gurufocus.com',
#   'categories': ['business'],
#   'relevance_score': 19.693558},
#  {'uuid': '571291ad-413f-4c82-98cf-60b2d8adb8b6',
#   'title': 'Quaintance, Arizona State Sun Devils square off against the Utah Utes',
#   'description': '',
#   'keywords': "Sports, Men's college basketball, College basketball, College sports, Article, 119319038",
#   'snippet': 'Quaintance, Arizona State Sun Devils square off against the Utah Utes\n\nBy The Associated Press\n\nArizona State Sun Devils (13-15, 4-13 Big 12) at Utah Utes (15-1...',
#   'url': 'https://abcnews.go.com/Sports/wireStory/quaintance-arizona-state-sun-devils-square-off-utah-119319038',
#   'image_url': 'https://s.abcnews.com/images/US/abc_news_default_2000x2000_update_16x9_992.jpg',
#   'language': 'en',
#   'published_at': '2025-03-01T08:45:57.000000Z',
#   'source': 'abcnews.go.com',
#   'categories': ['sports', 'general'],
#   'relevance_score': 19.670238},
#  {'uuid': '595156ee-7357-4ba0-b66a-4147be947016',
#   'title': 'Kansas State plays in Big 12 Tournament against the Arizona State',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Arizona State Sun Devils (13-18, 4-16 Big 12) vs. Kansas State Wildcats (15-16, 9-11 Big 12)\n\nKansas City, Missouri; Tuesday, 7 p.m. EDT\n\nBOTTOM LINE: Kansas St...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/10/kansas-state-plays-in-big-12-tournament-against-the-arizona-state',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-10T07:45:09.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 19.639563},
#  {'uuid': 'f90c0fdf-d099-4928-9b37-201bde61f0b6',
#   'title': '4 Killed in Arizona Highway Crash of Multiple Tractor-Trailers',
#   'description': 'Authorities in Arizona are investigating a crash that killed four people and left two in critical condition after several tractor-trailers collided with',
#   'keywords': '',
#   'snippet': 'Authorities in Arizona are investigating a crash that killed four people and left two in critical condition after several tractor-trailers collided with nearby ...',
#   'url': 'https://www.insurancejournal.com/news/west/2025/03/04/814033.htm',
#   'image_url': 'https://www.insurancejournal.com/img/social/opengraph/ij-social-default-1200x630.png',
#   'language': 'en',
#   'published_at': '2025-03-04T06:00:19.000000Z',
#   'source': 'insurancejournal.com',
#   'categories': ['business'],
#   'relevance_score': 19.618711},
#  {'uuid': 'fee6d6c4-b739-4657-88fc-9151bc873168',
#   'title': 'Duke-Arizona Sweet 16 matchup will complete March Madness trilogy',
#   'description': "One of the most anticipated matchups in this year's NCAA Tournament is Thursday's Sweet 16 contest between No. 4-seeded Arizona and No. 1-seeded Duke.",
#   'keywords': '',
#   'snippet': "In 2001, Duke defeated Arizona in the national title game, 82-72. It would be the third national championship of head coach Mike Krzyzewski's tenure.\n\nA decade ...",
#   'url': 'https://www.yardbarker.com/college_basketball/articles/duke_arizona_sweet_16_matchup_will_complete_march_madness_trilogy/s1_13132_41956881',
#   'image_url': 'https://www.yardbarker.com/media/0/4/04512156820be0fc031d225428f9b229bbb0cd9a/thumb_16x9/duke-arizona-sweet-16-matchup-complete-march.jpg?v=1',
#   'language': 'en',
#   'published_at': '2025-03-25T22:21:41.000000Z',
#   'source': 'yardbarker.com',
#   'categories': ['sports'],
#   'relevance_score': 19.618711},
#  {'uuid': '8c5ff324-9f57-44a2-ae29-7e3111f8205a',
#   'title': 'Democratic Rep. Raúl Grijalva of Arizona dies at 77',
#   'description': 'The 12-term congressman announced in April that he was being treated for lung cancer.',
#   'keywords': '',
#   'snippet': 'Rep. Raúl Grijalva, a 12-term Arizona Democrat who was a leading voice on immigration policy and expanding protection for public lands, died on March 13. He wa...',
#   'url': 'https://www.washingtonpost.com/obituaries/2025/03/13/raul-grijalva-dies-77-arizona-congressman/',
#   'image_url': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/X7U25BADYEI6TFMMBJQBEJX7NM_size-normalized.jpg&w=1440',
#   'language': 'en',
#   'published_at': '2025-03-14T01:32:28.000000Z',
#   'source': 'washingtonpost.com',
#   'categories': ['politics', 'general'],
#   'relevance_score': 19.618473},
#  {'uuid': 'e8d1ad6d-6dcf-4b2c-9ae5-0837f35a94e5',
#   'title': 'Crypto Reserve Status Draws Closer for Arizona on Senate Confirmations',
#   'description': "Key Takeaways: Arizona's Senate passed two bills pushing the state closer to establishing a crypto reserve. The bills aim to manage seized crypto and",
#   'keywords': '',
#   'snippet': 'Key Takeaways:\n\nArizona’s Senate passed two bills pushing the state closer to establishing a crypto reserve.\n\nThe bills aim to manage seized crypto and explor...',
#   'url': 'https://www.cryptoninjas.net/news/crypto-reserve-status-draws-closer-for-arizona-on-senate-confirmations/',
#   'image_url': 'https://www.cryptoninjas.net/wp-content/uploads/crypto-reserve-status-draws-closer-for-arizona-on-senate-confirmations.jpg',
#   'language': 'en',
#   'published_at': '2025-02-28T11:33:28.000000Z',
#   'source': 'cryptoninjas.net',
#   'categories': [],
#   'relevance_score': 19.617197},
#  {'uuid': '6df69ec9-2d0c-4f6e-9aca-f8103b0a3759',
#   'title': 'TSMC Announces $100 Billion U.S. Arizona Chip Investment Plan',
#   'description': 'March 4 - Taiwan Semiconductor Manufacturing Company (TSMC, Financial) is set to boost its U.S. presence with a planned $100 billion investment in a modern chip',
#   'keywords': 'GuruFocus, Article, News, Nauman khan, TSM',
#   'snippet': 'March 4 - Taiwan Semiconductor Manufacturing Company (TSMC, Financial) is set to boost its U.S. presence with a planned $100 billion investment in a modern chip...',
#   'url': 'https://www.gurufocus.com/news/2726105/tsmc-announces-100-billion-us-arizona-chip-investment-plan',
#   'image_url': 'https://static.gurufocus.com/logos/0C00000CIF.png?14',
#   'language': 'en',
#   'published_at': '2025-03-04T12:46:48.000000Z',
#   'source': 'gurufocus.com',
#   'categories': ['business'],
#   'relevance_score': 19.613815},
#  {'uuid': 'f1339986-283c-433a-87cf-05d454565007',
#   'title': 'Storm dumps heavy snow on northern Arizona, gridlocking Interstate 40',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'PARKS, Ariz. (AP) — A winter storm dumped heavy snow across northern Arizona on Friday, playing a major factor in a more than 15-mile (24-kilometer) backup on...',
#   'url': 'https://www.winnipegfreepress.com/arts-and-life/life/greenpage/2025/03/07/storm-dumps-heavy-snow-on-northern-arizona-gridlocking-interstate-40',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2025/02/06378a2116027fa1baaf8c9cfdc4cb5d4084d0ad209658b7e096bb0f2e1ca651.jpg',
#   'language': 'en',
#   'published_at': '2025-03-08T02:55:03.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': [],
#   'relevance_score': 19.605844},
#  {'uuid': 'ab42551f-b135-42eb-9704-ffe78318d922',
#   'title': 'The Ensign Group Continues Growth in Arizona',
#   'description': '**media[556074]**',
#   'keywords': 'The, Ensign, Group, Continues, Growth, in, Arizona',
#   'snippet': 'SAN JUAN CAPISTRANO, Calif., March 03, 2025 (GLOBE NEWSWIRE) -- The Ensign Group, Inc. (Nasdaq: ENSG), the parent company of the EnsignTM group of companies, wh...',
#   'url': 'https://www.manilatimes.net/2025/03/04/tmt-newswire/globenewswire/the-ensign-group-continues-growth-in-arizona/2066374',
#   'image_url': 'https://www.manilatimes.net/manilatimes/uploads/images/2025/03/04/556074.jpg',
#   'language': 'en',
#   'published_at': '2025-03-03T21:14:18.000000Z',
#   'source': 'manilatimes.net',
#   'categories': ['business', 'general'],
#   'relevance_score': 19.580477},
#  {'uuid': 'dcefd24b-16df-441f-9b83-2a8ed23b942d',
#   'title': 'Intel Fabricates 18A Test Wafers in Arizona',
#   'description': 'Plants in two states are now 1.8nm class capable.',
#   'keywords': '18A, Pankaj Marria, Intel, Lip-Bu Tan',
#   'snippet': "Yahoo is using AI to generate takeaways from this article. This means the info may not always match what's in the article. Reporting mistakes helps us improve t...",
#   'url': 'https://www.yahoo.com/tech/intel-fabricates-18a-test-wafers-110000619.html',
#   'image_url': 'https://s.yimg.com/ny/api/res/1.2/Zud9hlebHWQwiSAIdR66PQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02Mjc-/https://media.zenfs.com/en/extreme_tech_articles_222/336c1c40452537f5bd89dd2af99aa2b5',
#   'language': 'en',
#   'published_at': '2025-03-18T11:00:00.000000Z',
#   'source': 'yahoo.com',
#   'categories': ['general', 'business', 'sports', 'entertainment'],
#   'relevance_score': 19.580477},
#  {'uuid': '9e5e272d-7a0b-4f0c-b044-f75f819d3c77',
#   'title': "Statewide Enrollment Now Open for Arizona Connections Academy's 2025-2026 School Year",
#   'description': '/PRNewswire-PRWeb/ -- Families and students seeking a flexible, experienced and high-quality education are now welcome to enroll in Arizona Connections Academy....',
#   'keywords': 'Arizona Connections Academy',
#   'snippet': 'I believe that online learning can be a wonderful option for students who need increased flexibility, rigor or individualization. Expanding our college and earl...',
#   'url': 'https://www.prweb.com/releases/statewide-enrollment-now-open-for-arizona-connections-academys-2025-2026-school-year-302406254.html',
#   'image_url': 'https://mma.prnewswire.com/media/2643760/CA_Arizona_med_bw.jpg?p=facebook',
#   'language': 'en',
#   'published_at': '2025-03-20T15:00:00.000000Z',
#   'source': 'prweb.com',
#   'categories': ['business'],
#   'relevance_score': 19.556465},
#  {'uuid': '18aed0d8-2120-4ddb-937e-9889ffec1703',
#   'title': 'The 20 Most Expensive ZIP Codes In Arizona, From Zillow Data',
#   'description': 'Find out where you can see the most expensive ZIP codes in Arizona.',
#   'keywords': '',
#   'snippet': 'Mixed use modern development on the banks of the Arizona Canal on a sunny day in Scottsdale. Many of ... [+] the most expensive ZIP codes cover or are within th...',
#   'url': 'https://www.forbes.com/sites/andrewdepietro/2025/02/27/the-20-most-expensive-zip-codes-in-arizona-from-zillow-data/',
#   'image_url': 'https://imageio.forbes.com/specials-images/imageserve/67c09cf9f1309fb4809bc3f1/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'language': 'en',
#   'published_at': '2025-02-27T17:13:39.000000Z',
#   'source': 'forbes.com',
#   'categories': ['business', 'general'],
#   'relevance_score': 19.4949},
#  {'uuid': '318f1fdb-b6e3-4a7a-bf3d-09e22f0cf06c',
#   'title': "Toll Brothers' Arizona Division Wins Four Gold Awards at The Nationals",
#   'description': "SCOTTSDALE, Ariz., March  04, 2025  (GLOBE NEWSWIRE) -- Toll Brothers, Inc. (:TOL), the nation's leading builder of luxury homes, was recently honored with four",
#   'keywords': 'GuruFocus, Article, News, Marketwired, TOL',
#   'snippet': 'SCOTTSDALE, Ariz., March 04, 2025 (GLOBE NEWSWIRE) -- Toll Brothers, Inc. (:TOL), the nation’s leading builder of luxury homes, was recently honored with four...',
#   'url': 'https://www.gurufocus.com/news/2727409/toll-brothers-arizona-division-wins-four-gold-awards-at-the-nationals',
#   'image_url': 'https://static.gurufocus.com/images/global_logo_twitter_card.png',
#   'language': 'en',
#   'published_at': '2025-03-04T21:00:02.000000Z',
#   'source': 'gurufocus.com',
#   'categories': ['business'],
#   'relevance_score': 19.487076},
#  {'uuid': '785e4a51-629a-403f-a120-9f85966a7026',
#   'title': 'Arizona SkillsUSA competition showcases trade options',
#   'description': 'The Arizona Builders Alliance event featured more than 140 students entering contests in various craft categories.',
#   'keywords': '',
#   'snippet': 'Listen to the article 4 min This audio is auto-generated. Please let us know if you have feedback\n\nThe construction industry faces a stark shortage of workers, ...',
#   'url': 'https://www.constructiondive.com/news/arizona-skillsusa-contest-high-school-trades/743717/',
#   'image_url': 'https://imgproxy.divecdn.com/Rs_G7RGN4Ojxc3Uf-Utg7tGC3grQwljezYSCX1t-YGI/g:ce/rs:fit:770:435/Z3M6Ly9kaXZlc2l0ZS1zdG9yYWdlL2RpdmVpbWFnZS9BQkExLmpwZw==.webp',
#   'language': 'en',
#   'published_at': '2025-03-27T16:44:00.000000Z',
#   'source': 'constructiondive.com',
#   'categories': [],
#   'relevance_score': 19.475925},
#  {'uuid': 'b1084bda-b3f0-4b2b-993d-d25ddaa0143b',
#   'title': 'Killer NJ mom who fatally drugged daughters commits suicide in Arizona prison',
#   'description': 'Cruse, 38, admitted killing her kids, Aleyah McIntyre, 9, and Royal McIntyre, 4, shortly after moving from Pleasantville, New Jersey, to Arizona in 2021.',
#   'keywords': 'US News, Metro, arizona, mothers and daughters, murders, new jersey, suicide, true crime',
#   'snippet': 'A New Jersey mother serving a pair of life sentences in Arizona for the murder of her two young daughters was found dead in her prison cell last week.\n\nRetta Cr...',
#   'url': 'https://nypost.com/2025/03/01/us-news/nj-woman-retta-cruse-commits-suicide-in-prison-after-killing-daughters/',
#   'image_url': 'https://nypost.com/wp-content/uploads/sites/2/2025/02/99385227-1.jpg?quality=75&strip=all&w=1024',
#   'language': 'en',
#   'published_at': '2025-03-01T15:16:16.000000Z',
#   'source': 'nypost.com',
#   'categories': ['general'],
#   'relevance_score': 19.468418},
#  {'uuid': '98a4e87b-d577-446d-b226-97d789b5b93c',
#   'title': 'Arizona Diamondbacks give Justin Martinez five-year contract',
#   'description': 'In a deal that was announced on Saturday, Arizona hard-throwing right-hander Justin Martinez agreed to an $18 million, five-year contract even as he continues t...',
#   'keywords': '',
#   'snippet': 'Open Extended Reactions\n\nPHOENIX -- Arizona hard-throwing right-hander Justin Martinez has agreed to an $18 million, five-year contract even as he continues to ...',
#   'url': 'https://www.espn.com/mlb/story/_/id/44362614/arizona-diamondbacks-give-justin-martinez-five-year-contract',
#   'image_url': 'https://a.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F0322%2Fr1467920_1296x729_16%2D9.jpg',
#   'language': 'en',
#   'published_at': '2025-03-22T23:55:03.000000Z',
#   'source': 'espn.com',
#   'categories': ['sports'],
#   'relevance_score': 19.414326},
#  {'uuid': '1da01999-b833-4ca0-bb26-56f8826fc562',
#   'title': "Arizona tribes unite in support after teen's tragic death",
#   'description': 'The Pascua Yaqui Tribe held a walk and vigil for the murdered teen, to support the San Carlos Apache Tribe. This as a new $75,000 reward is announced.',
#   'keywords': '',
#   'snippet': 'The Pascua Yaqui tribe walked and prayed for the murdered teen on Sunday in the town of Guadalupe.\n\nExample video title will go here for this video\n\nNext up in ...',
#   'url': 'https://www.ktvb.com/article/news/nation-world/emily-pike-murder-mmiw-indigenous-tribes-support-san-carlos-apache-tribe/75-54f6428f-5d58-4983-874b-de55d66dbda1',
# ...
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'SCOTTSDALE, Ariz. (AP) — A security guard at an Arizona hospital was shot and wounded over the weekend, and the man suspected in the attack was quickly disarm...',
#   'url': 'https://www.winnipegfreepress.com/arts-and-life/life/health/2025/03/03/emergency-room-security-guard-shot-and-wounded-in-arizona-man-arrested',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2022/11/fb-og-image.png',
#   'language': 'en',
#   'published_at': '2025-03-04T00:47:57.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 15.06572},
#  {'uuid': '0da02acf-08e4-49f7-915f-0b66d82ccf9d',
#   'title': '‘Heavily loved’ Arizona yoga teacher vanishes after going to meet blind date',
#   'description': "Beloved Phoenix yoga teacher Marcus Freiberger, 45, went to meet a blind date om Feb. 21 — and hasn't been seen since, leaving his dad, friends and students d...",
#   'keywords': 'US News, arizona, missing persons, phoenix',
#   'snippet': 'A “handsome” and “heavily loved” Arizona yoga teacher has been missing for nearly a month after going to meet up with a blind date, according to concern...',
#   'url': 'https://nypost.com/2025/03/21/us-news/ariz-yoga-teacher-marcus-freiberger-vanishes-after-going-to-meet-blind-date/',
#   'image_url': 'https://nypost.com/wp-content/uploads/sites/2/2025/03/marcus-teaching-yoga-melrose-yoga-100878746.jpg?quality=75&strip=all&w=1024',
#   'language': 'en',
#   'published_at': '2025-03-22T01:52:56.000000Z',
#   'source': 'nypost.com',
#   'categories': ['general'],
#   'relevance_score': 14.981134},
#  {'uuid': 'd517a964-c27d-4236-9828-1c85c05a8b54',
#   'title': 'Arizona woman, 47, accused of mounting relentless harassment campaign — including leaking nudes — after falling out with ex-friend',
#   'description': 'An Arizona woman is accused of mounting a relentless harassment campaign against her former friend – including sending a nude photo of the ex-pal to a member ...',
#   'keywords': 'US News, arizona, crime, stalkers, stalking',
#   'snippet': 'An Arizona woman is accused of mounting a relentless harassment campaign against her former friend – including sending a nude photo of the ex-pal to a member ...',
#   'url': 'https://nypost.com/2025/03/11/us-news/arizona-woman-47-accused-of-mounting-relentless-harassment-campaign-including-leaking-nudes-after-falling-out-with-ex-friend/',
#   'image_url': 'https://nypost.com/wp-content/uploads/sites/2/2025/03/arizona-woman-accused-stalking-former-100251809.jpg?quality=75&strip=all&w=1024',
#   'language': 'en',
#   'published_at': '2025-03-11T06:58:22.000000Z',
#   'source': 'nypost.com',
#   'categories': ['general'],
#   'relevance_score': 14.933859},
#  {'uuid': 'da688616-59e3-4fa2-91f6-228d485e4c80',
#   'title': 'Mexico seizes 275,000 fentanyl pills from boxes of sliced cactus bound for Arizona',
#   'description': 'Authorities found 70 pounds of fentanyl hidden inside boxes of slices of cactus, a Mexican food stable known as nopales.',
#   'keywords': 'Health, Mexico, Arizona, Donald Trump, Opioids',
#   'snippet': 'Authorities in northern Mexico on Wednesday found about 70 pounds of fentanyl hidden inside boxes of sliced cactus, a quintessential Mexican food staple known a...',
#   'url': 'https://www.cbsnews.com/news/mexico-fentanyl-seizure-united-states-arizona-cactus/',
#   'image_url': 'https://assets2.cbsnewsstatic.com/hub/i/r/2023/04/14/03e26477-4b91-4c6a-b680-479db9a986b8/thumbnail/1200x630/03c6ee8a4d9d9bd9c0b4bd3aa659bfbe/gettyimages-609942782.jpg?v=63a2b43e2ef8917aa6bd547ca29dd4fa',
#   'language': 'en',
#   'published_at': '2025-03-06T16:09:51.000000Z',
#   'source': 'cbsnews.com',
#   'categories': ['general'],
#   'relevance_score': 14.929401},
#  {'uuid': 'f43c1985-66f8-4034-b5b3-02ccccf5ab62',
#   'title': 'Two Docs Accused of Sexual Abuse; Arizona Hospital Shooting; Nurse Accused of Murder',
#   'description': "A weekly roundup of healthcare's encounters with the courts",
#   'keywords': '',
#   'snippet': 'Two Tennessee physicians are facing sexual abuse allegations. Sanjeev Kumar, MD, has been accused of coercing at least four women to travel to Memphis to perfor...',
#   'url': 'https://www.medpagetoday.com/special-reports/features/114522',
#   'image_url': 'https://assets.medpagetoday.net/media/images/114xxx/114522.jpg',
#   'language': 'en',
#   'published_at': '2025-03-06T17:37:46.000000Z',
#   'source': 'medpagetoday.com',
#   'categories': ['health'],
#   'relevance_score': 14.708298},
#  {'uuid': 'ef10bc2a-9f78-426c-9092-439221356063',
#   'title': 'TSMC Arizona Corporation is seeking a Facilities Service Coordinator (Multiple Positions) in Phoenix, AZ',
#   'description': 'Facilities Service Coordinator (Multiple Positions), TSMC Arizona Corporation, Phoenix, AZ. Conduct building inspections to ensure the aesthetic and architectur...',
#   'keywords': '',
#   'snippet': 'Job Description\n\nFacilities Service Coordinator (Multiple Positions), TSMC Arizona Corporation, Phoenix, AZ. Conduct building inspections to ensure the aestheti...',
#   'url': 'https://www.coroflot.com/design-jobs/Facilities-Service-Coordinator-Multiple-Positions-TSMC-Arizona-Corporation-Phoenix-AZ-565563',
#   'image_url': 'https://www.coroflot.com/images/page_icons/apple-touch-icon-57x57.png',
#   'language': 'en',
#   'published_at': '2025-03-18T18:45:00.000000Z',
#   'source': 'coroflot.com',
#   'categories': ['entertainment'],
#   'relevance_score': 14.673618},
#  {'uuid': '7013b39b-e97d-4296-adc6-aa76bf84f1f0',
#   'title': 'Police identify 2 people who died in Feb. 19 midair collision at southern Arizona airport',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'MARANA, Ariz. (AP) — Authorities have publicly identified two people killed two weeks ago in the midair collision of two small planes at a southern Arizona ai...',
#   'url': 'https://www.winnipegfreepress.com/world/2025/03/06/police-identify-2-people-who-died-in-feb-19-midair-collision-at-southern-arizona-airport',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2025/02/17aaa9f80aeb50cd88a5b80cb6159749e28279dc532f5bfbbbf775684f3b291c.jpg',
#   'language': 'en',
#   'published_at': '2025-03-06T18:31:28.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': [],
#   'relevance_score': 14.669955},
#  {'uuid': '84394ce4-c40c-460f-a5c2-d64149d3695e',
#   'title': 'Arizona woman, 47, accused of mounting relentless harassment campaign — including leaking nudes — after falling out with ex-friend',
#   'description': 'The case involving Arizona woman Christina Lynn Holt, 47, and her friend Jerry Huntington, who ended up as her ex-pal, has been charged with several offenses.',
#   'keywords': '',
#   'snippet': 'The case involving Arizona woman Christina Lynn Holt, 47, and her friend Jerry Huntington, who ended up as her ex-pal, has been charged with several offenses. A...',
#   'url': 'https://commstrader.com/news/arizona-woman-47-accused-of-mounting-relentless-harassment-campaign-including-leaking-nudes-after-falling-out-with-ex-friend/',
#   'image_url': 'https://commstrader.com/wp-content/uploads/2025/03/arizona-woman-accused-stalking-former-100251809.jpg',
#   'language': 'en',
#   'published_at': '2025-03-11T08:37:31.000000Z',
#   'source': 'uctoday.com',
#   'categories': ['tech'],
#   'relevance_score': 14.633271},
#  {'uuid': '649aa61a-a419-44e4-969d-b4d384073d75',
#   'title': 'Maliq Brown could return from a shoulder injury to play in Duke’s Sweet 16 game against Arizona',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'NEWARK, N.J. (AP) — Duke’s Maliq Brown, out since the ACC Tournament with a shoulder injury, is a “maybe” for the Blue Devils’ Sweet 16 game against A...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/26/maliq-brown-could-return-from-a-shoulder-injury-to-play-in-dukes-sweet-16-game-against-arizona',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2025/03/8e1e06574ad25588b3d588942ce7a2ba76dff5de42aeba42b4c8f4c42212b11e.jpg',
#   'language': 'en',
#   'published_at': '2025-03-26T20:05:37.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': [],
#   'relevance_score': 14.355236},
#  {'uuid': 'f37fa38b-99a9-428b-982a-53d40c4820b9',
#   'title': "'Tesla, you’re fired!': Arizona senator ditches his Tesla week after Elon Musk calls him a 'traitor'",
#   'description': 'Sen. Mark Kelly of Arizona posted a video on X explaining that this would be his last trip in the car, and he was looking for a new one.',
#   'keywords': '',
#   'snippet': 'Sen. Kelly joins a growing list of public figures protesting the electric vehicle manufacturer.\n\nPHOENIX — U.S. Senator Mark Kelly of Arizona is joining a gro...',
#   'url': 'https://www.kvue.com/article/news/politics/rolling-billboard-for-man-dismantling-our-government-sen-mark-kelly-tesla-protest/75-c88ef0d0-d04e-4027-bcdd-9b08bf569a7c',
#   'image_url': 'https://media.kvue.com/assets/KPNX/images/bc826d8c-c53f-44bd-b660-2f7ddfddb6e9/20250314T172050/bc826d8c-c53f-44bd-b660-2f7ddfddb6e9_1140x641.jpg',
#   'language': 'en',
#   'published_at': '2025-03-15T15:39:36.000000Z',
#   'source': 'kvue.com',
#   'categories': ['general'],
#   'relevance_score': 14.207195},
#  {'uuid': '8b1326fa-68bc-4499-ac7c-4d40c3cabbbf',
#   'title': 'WaBa Grill To Broaden Arizona Footprint With Third Location, Opening Spring',
#   'description': 'Growing Rice Bowl Chain Set to Open in Laveen Village in April',
#   'keywords': 'restaurant, restaurant franchise, restaurant news, rice bowl chain, waba grill, waba grill franchise',
#   'snippet': 'Growing Rice Bowl Chain Set to Open in Laveen Village in April\n\nAnaheim Hills, CA ( RestaurantNews.com ) WaBa Grill , an LA-original rice bowl chain known for i...',
#   'url': 'http://www.restaurantnews.com/waba-grill-to-broaden-arizona-footprint-with-third-location-opening-spring-022725/',
#   'image_url': 'http://www.restaurantnews.com/wp-content/uploads/2025/02/WaBa-Grill-To-Broaden-Arizona-Footprint-With-Third-Location-Opening-Spring-feature.jpg',
#   'language': 'en',
#   'published_at': '2025-02-27T10:49:45.000000Z',
#   'source': 'restaurantnews.com',
#   'categories': ['food', 'travel', 'business'],
#   'relevance_score': 14.200542},
#  {'uuid': '5752eca3-f595-4709-954a-494595667003',
#   'title': 'HUGE: Maricopa County Officials KNEW About Ballot Paper and Ink Concerns Before Arizona 2022 Election, Still Allowed 60% of Machines to Spit Out Ballots on Election Day – Elon Musk Responds!',
#   'description': "U.S. Rep. Abe Hamadeh's bold statements regarding alleged election misconduct in Arizona raise critical questions about integrity and accountability. This post ...",
#   'keywords': '',
#   'snippet': 'As Arizona voters remember the rigged 2022 election, stolen by the corrupt Democrats and Trump-hating RINO Maricopa County officials, new details have emerged s...',
#   'url': 'https://www.thegatewaypundit.com/2025/03/huge-maricopa-county-officials-knew-about-ballot-paper/',
#   'image_url': 'https://www.thegatewaypundit.com/wp-content/uploads/180FFE72-025C-490E-A3DB-61723309B3E2.jpeg',
#   'language': 'en',
#   'published_at': '2025-03-02T16:45:17.000000Z',
#   'source': 'thegatewaypundit.com',
#   'categories': ['politics', 'general'],
#   'relevance_score': 14.062948},
#  {'uuid': '851fe748-c1c1-461f-8ef1-f79d24d587e3',
#   'title': 'USWNT star Sophia Wilson and husband, Arizona Cardinals wide receiver Michael Wilson, announce pregnancy',
#   'description': "A timetable for the forward's return to NWSL and USA Soccer action hasn't yet been determined",
#   'keywords': '',
#   'snippet': "U.S. women's national team striker and Portland Thorns FC forward Sophia Wilson (formerly Smith) announced she and her husband are expecting their first child. ...",
#   'url': 'https://www.cbssports.com/soccer/news/uswnt-star-sophia-wilson-and-husband-arizona-cardinals-wide-receiver-michael-wilson-announce-pregnancy/',
#   'image_url': 'https://sportshub.cbsistatic.com/i/r/2025/03/04/2f8bb10b-56e3-4e71-9925-ee32d858a100/thumbnail/1200x675/c0782b627e217966964dd2dce070dfba/soph.jpg',
#   'language': 'en',
#   'published_at': '2025-03-05T17:48:00.000000Z',
#   'source': 'cbssports.com',
#   'categories': ['sports'],
#   'relevance_score': 13.868391},
#  {'uuid': '6a44983c-d18a-445e-9369-ffa02ba8209b',
#   'title': "Judge to allow camera in Lori Vallow Daybell's Arizona trial; defense releases witness list",
#   'description': 'Maricopa County Superior Court Judge Justin Beresky decided during a Tuesday hearing and said one pool camera will be allowed to provide a livestream to media o...',
#   'keywords': 'news, traffic, weather, sports, classifieds, cars, jobs, homes, television, radio, salt lake, utah, local',
#   'snippet': "Estimated read time: 2-3 minutes\n\nPHOENIX — A judge will allow a camera in the courtroom during Lori Vallow Daybell's upcoming trial in Arizona.\n\nMaricopa Cou...",
#   'url': 'https://www.ksl.com/article/51273085/judge-to-allow-camera-in-lori-vallow-daybells-arizona-trial-defense-releases-witness-list',
#   'image_url': 'https://img.ksl.com/slc/3046/304618/30461899.jpeg?filter=kslv2/responsive_story_lg',
#   'language': 'en',
#   'published_at': '2025-03-12T00:18:00.000000Z',
#   'source': 'ksl.com',
#   'categories': [],
#   'relevance_score': 13.868391},
#  {'uuid': '37bf8b16-51a8-4f17-878b-28afdc89d1d0',
#   'title': 'Minnesota’s singing McDonald’s drive-thru star takes act to Arizona',
#   'description': 'Daniel Marshall gained fans during COVID by singing to customers at the McDonalds in Arden Hills, Minnesota.',
#   'keywords': '',
#   'snippet': 'Daniel Marshall gained fans during COVID singing to customers at the McDonalds in Arden Hills, Minnesota.\n\nARDEN HILLS, Minn. — Editor’s Note: This story or...',
#   'url': 'https://www.kare11.com/article/news/local/land-of-10000-stories/minnesotas-singing-mcdonalds-drive-thru-star-takes-act-arizona/89-19d20b3e-a686-43fc-b114-6d17ba3aedfa',
#   'image_url': 'https://media.kare11.com/assets/KARE/images/df824ee0-44cd-4c13-b3c1-9edf495687cb/20250318T004030/df824ee0-44cd-4c13-b3c1-9edf495687cb_1140x641.jpg',
#   'language': 'en',
#   'published_at': '2025-03-18T02:00:00.000000Z',
#   'source': 'kare11.com',
#   'categories': ['general'],
#   'relevance_score': 13.856299},
#  {'uuid': '06c8ae2c-2ff0-4348-a1a8-96a025e5d401',
#   'title': 'Duke gets No. 1 regional seed for March Madness, headlines East with Alabama, Wisconsin, Arizona',
#   'description': 'Breaking News, Sports, Manitoba, Canada',
#   'keywords': '',
#   'snippet': 'Duke headlines the NCAA Tournament’s East Region as a No. 1 seed and will open the push for the program’s sixth national title with a short drive from campu...',
#   'url': 'https://www.winnipegfreepress.com/uncategorized/2025/03/16/duke-gets-no-1-regional-seed-for-march-madness-headlines-east-with-alabama-wisconsin-arizona',
#   'image_url': 'https://www.winnipegfreepress.com/wp-content/uploads/sites/2/2025/03/c0ef92919e5201bed6f3dc82c9470510607fefa17d0893efcbcd8a0d5026ba59.jpg',
#   'language': 'en',
#   'published_at': '2025-03-16T22:36:23.000000Z',
#   'source': 'winnipegfreepress.com',
#   'categories': ['general'],
#   'relevance_score': 13.810841},
#  {'uuid': 'f16a4ec5-b850-4f3b-bb33-47a408058104',
#   'title': 'NTSB Scrutinizes Landing Gear in Learjet Accident in Arizona',
#   'description': 'NTSB investigators are focusing on landing gear failure as a possible factor leading to two business jets colliding in Arizona last month.',
#   'keywords': '',
#   'snippet': 'Federal accident investigators are focusing on landing gear failure as a possible factor that led to the death of one person and injured three others when two b...',
#   'url': 'https://www.flyingmag.com/ntsb-scrutinizes-landing-gear-in-learjet-accident-in-arizona/',
#   'image_url': 'https://www.flyingmag.com/uploads/2025/03/NTSB.jpg?auto=webp',
#   'language': 'en',
#   'published_at': '2025-03-03T17:09:33.000000Z',
#   'source': 'flyingmag.com',
#   'categories': ['tech'],
#   'relevance_score': 13.770459}]

# %%
def analyze_news(news_articles):
    results = []

    for article in news_articles:
        title = article.get("title", "No title")
        description = article.get("description", "No description")
        content = article.get("snippet", "No content")
        if not content:
            continue

        # Summarization
        summary = summarize_article(content)

        # Sentiment Analysis
        sentiment = analyze_sentiment(content)

        # Prepare content for topic modeling
        results.append({
            "title": title,
            "summary": summary,
            "sentiment": sentiment
        })

    # Topic Modeling
    contents = [article['summary'] for article in results]
    topics = extract_topics(contents)

    return results, topics


analyzed_articles, topics = analyze_news(arizona_articles)

# Display results
for article in analyzed_articles:
    print(f"Title: {article['title']}")
    print(f"Summary: {article['summary']}")
    print(f"Sentiment: {article['sentiment']}")
    print('-' * 80)

# Display topics
print("\nDetected Topics:")
for topic_id, articles in topics.items():
    print(f"\nTopic {topic_id + 1}:")
    for art in articles[:3]:  # Show first 3 articles per topic
        print(f"- {art}")
# Out:
# Title: Ranking Arizona: Top 10 Italian restaurants in Arizona for 2025
# Summary: Featured
#
# Here are the Top 10 Italian restaurants in Arizona, based on public voting for the 2025 edition of Ranking Arizona, the state’s biggest and most com...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Arizona State faces No. 22 Arizona after Sanon’s 28-point showing
# Summary: Arizona State Sun Devils (13-16, 4-14 Big 12) at Arizona Wildcats (19-10, 13-6 Big 12)
#
# Tucson, Arizona; Tuesday, 11 p.m. EST
#
# BOTTOM LINE: Arizona State visits...
# Sentiment: 3
# --------------------------------------------------------------------------------
# Title:

# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Chicago Cubs to face the Arizona Diamondbacks two best starters
# Summary: The Chicago Cubs will return to playing spring training games tomorrow after they return from their trip to Japan.
#
# The Cubs dropped both games in the Tokyo Ser...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Chicago Cubs: Arizona Diamondbacks reveal pitching matchups for opening series
# Summary: The Chicago Cubs will return to playing spring training games tomorrow after they return from their trip to Japan.
#
# The Cubs dropped both games in the Tokyo Ser...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Houston vs. Arizona odds, prediction: BetMGM Sportsbook bonus code POSTBET
# Summary: Gambling content 21+. The New York Post may receive an affiliate commission if you sign up through our links. Read our editorial standards for more information....
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Arizona and Oregon play in second round of NCAA Tournament
# Summary: Oregon Ducks (25-9, 13-9 Big Ten) vs. Arizona Wildcats (23-12, 16-8 Big 12)
#
# Seattle; Sunday, 9:40 p.m. EDT
#
# BETMGM SPORTSBOOK LINE: Wildcats -3.5; over/under i...
# Sentiment: 3
# --------------------------------------------------------------------------------
# Title: Arizona laws ordering citizenship proof struck down by appeals court
# Summary: A federal appeals court struck down provisions in two Arizona voting laws that sought to increase proof-of-citizenship requirements for voter registration, sayi...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Arizona executes man by lethal injection for 2002 murder
# Summary: A 53-year-old man convicted of murder was put to death by lethal injection in Arizona on Wednesday in the first execution in the southwestern U.S. state in more...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Report: Arizona State expected to bring back Bobby Hurley
# Summary: Open Extended Reactions
#
# TEMPE, Ariz. -- Arizona State coach Bobby Hurley is expected to return for his 11th season, a source told the Associated Press, confirm...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: The Ensign Group Continues Growth in Arizona
# Summary: SAN JUAN CAPISTRANO, Calif., March 03, 2025 (GLOBE NEWSWIRE) -- The Ensign Group, Inc. ( ENSG), the parent company of the EnsignTM group of companies, which inv...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Quaintance, Arizona State Sun Devils square off against the Utah Utes
# Summary: Quaintance, Arizona State Sun Devils square off against the Utah Utes
#
# By The Associated Press
#
# Arizona State Sun Devils (13-15, 4-13 Big 12) at Utah Utes (15-1...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Kansas State plays in Big 12 Tournament against the Arizona State
# Summary: Arizona State Sun Devils (13-18, 4-16 Big 12) vs. Kansas State Wildcats (15-16, 9-11 Big 12)
#
# Kansas City, Missouri; Tuesday, 7 p.m. EDT
#
# BOTTOM LINE: Kansas St...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: 4 Killed in Arizona Highway Crash of Multiple Tractor-Trailers
# Summary: Authorities in Arizona are investigating a crash that killed four people and left two in critical condition after several tractor-trailers collided with nearby ...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Duke-Arizona Sweet 16 matchup will complete March Madness trilogy
# Summary: In 2001, Duke defeated Arizona in the national title game, 82-72. It would be the third national championship of head coach Mike Krzyzewski's tenure.
#
# A decade ...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Democratic Rep. Raúl Grijalva of Arizona dies at 77
# Summary: Rep. Raúl Grijalva, a 12-term Arizona Democrat who was a leading voice on immigration policy and expanding protection for public lands, died on March 13. He wa...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Crypto Reserve Status Draws Closer for Arizona on Senate Confirmations
# Summary: Key Takeaways:
#
# Arizona’s Senate passed two bills pushing the state closer to establishing a crypto reserve.
#
# The bills aim to manage seized crypto and explor...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: TSMC Announces $100 Billion U.S. Arizona Chip Investment Plan
# Summary: March 4 - Taiwan Semiconductor Manufacturing Company (TSMC, Financial) is set to boost its U.S. presence with a planned $100 billion investment in a modern chip...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title:

# Sentiment: 3
# --------------------------------------------------------------------------------
# Title: Arizona executes man by lethal injection for 2002 murder
# Summary: A 53-year-old man convicted of murder was put to death by lethal injection in Arizona on Wednesday in the first execution in the southwestern US state in more t...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: [M] TSMC Arizona Operations Only 10% More Expensive Than Taiwanese Fab Operations
# Summary: TSMC Arizona Operations Only 10% More Expensive Than Taiwanese Fab Operations
#
# A recent study by TechInsights is reshaping the narrative around the cost of semi...
# Sentiment: 2
# --------------------------------------------------------------------------------
# Title: Industry Opposes Arizona Bill That Shields Utilities From Wildfire Liability
# Summary: Best’s News & Research Service subscription required - March 18, 2025 03:22 PM (EDT)
#
# Industry Opposes Arizona Bill That Shields Utilities From Wildfire Liabi...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Horrific multi-vehicle crash in Arizona leaves at least 6 dead, 13 injured
# Summary: An investigation is underway in Arizona after a multi-vehicle crash on Interstate 10 left at least six people dead and more than a dozen injured.
#
# According to ...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Arizona overwhelms Akron with 3s and dunks in 93-65 March Madness victory
# Summary: Jaden Bradley, Trey Townsend and Caleb Love hit 3-pointers within the first two minutes, and No. 4 seed Arizona easily dismissed 13th-seeded Akron 93-65 in the ...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: SKYDAN Expands Home Sale/Leaseback Program to Arizona and Florida
# Summary: "For years, we've helped Midwest families access their home-equity wealth and find financial freedom, and now we can bring that same opportunity to homeowners i...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Arizona Teen Found Dismembered, Police Won’t Reveal Suspects
# Summary: The remains of a missing fourteen-year-old from an Arizona Apache reservation were just discovered, but police are being very tight-lipped about the three suspe...
# Sentiment: 2
# --------------------------------------------------------------------------------
# Title: Arizona Wildcats and Oregon Ducks square off in NCAA Tournament second round
# Summary: Oregon Ducks (25-9, 13-9 Big Ten) vs. Arizona Wildcats (23-12, 16-8 Big 12)
#
# Seattle; Sunday, 9:40 p.m. EDT
#
# BOTTOM LINE: No. 21 Arizona and No. 25 Oregon play ...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Puma Arizona White / Dark Myrtle
# Summary: The Puma Arizona White / Dark Myrtle is a compelling addition to Puma's diverse lineup of footwear, blending modern design with classic elements. This shoe capt...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Arizona State RB Cam Skattebo, 2025 NFL Draft prospect, sued by former teammate
# Summary: National Football League Arizona State RB Cam Skattebo, 2025 NFL Draft prospect, sued by former teammate Updated Mar. 7, 2025 3:07 p.m. ET share facebook x redd...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Cam Skattebo sued by former Arizona State teammate over injury on practice field
# Summary: While former Arizona State running back Cam Skattebo has been at the Scouting Combine and preparing for pre-draft meetings with NFL teams, process servers have ...
# Sentiment: 3
# --------------------------------------------------------------------------------
# Title: Arizona to be 'model' of Taiwan-U.S. high-tech cooperation: Lai
# Summary: To activate the text-to-speech service, please first agree to the privacy policy below.
#
# Taipei, March 19 (CNA) TSMC's continued expansion in Arizona will becom...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Democratic Rep. Raúl M. Grijalva of Arizona dies at 77
# Summary: By STEPHEN GROVES and LEAH ASKARINAM, Associated Press
#
# WASHINGTON (AP) — Democratic U.S. Rep. Raúl M. Grijalva of Arizona, who championed environmental prot...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Arizona Cardinals radio analyst Ron Wolfley steps down after 20 seasons
# Summary: Dave Pasch and Ron Wolfley stand for the national anthem at State Farm Stadium in Glendale, Arizona. Photo via Brendon Kleen.
#
# Beloved local radio personality a...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Arizona and Akron square off in first round of NCAA Tournament
# Summary: Akron Zips (28-6, 20-1 MAC) vs. Arizona Wildcats (22-12, 16-8 Big 12)
#
# Seattle; Friday, 7:35 p.m. EDT
#
# BETMGM SPORTSBOOK LINE: Wildcats -14.5; over/under is 167...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Women’s basketball: CU Buffs rally past Arizona in Big 12 Tournament
# Summary: Fast break
#
# Why the Buffs won: They were composed in crunch time, making big plays on offense and defense down the stretch to overcome some miscues early in the...
# Sentiment: 2
# --------------------------------------------------------------------------------
# Title: Could Arizona become the first U.S. state with a crypto reserve?
# Summary: Arizona passed Bitcoin Reserve Bills, but Governor Katie Hobbs’s veto history adds uncertainty.
#
# Hobbs’s veto history adds uncertainty. U.S. states embrace ...
# Sentiment: 3
# --------------------------------------------------------------------------------
# Title: Arizona State fires women’s basketball coach Natasha Adair after 3 seasons
# Summary: TEMPE, Ariz. (AP) — Arizona State fired women’s basketball coach Natasha Adair on Saturday after three seasons of not making the NCAA Tournament.
#
# “We app...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: TSMC’s massive Arizona chips project praised by Taiwan’s president
# Summary: Taiwan’s President William Lai Ching-te said that a Taiwanese semiconductor company’s massive investment in Arizona is the “best model” for the island?...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: LivAway Suites Beaks Ground for Hotel in Surprise, Arizona
# Summary: LivAway Suites Beaks Ground for Hotel in Surprise, Arizona - Image Credit Livaway Suites
#
#
#
# LivAway Suites is expanding its presence in the Phoenix market with ...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Aaron Gunches' Final Actions Before Arizona Execution
# Summary: An Arizona man had no final words as he was executed for the 2002 kidnapping and murder of his then-girlfriend's ex-boyfriend on Wednesday.
#
# Aaron Brian Gunches...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Family Has Been Missing Since Arizona Winter Storm
# Summary: The Coconino County Sheriff's Office in Arizona has issued an appeal for information on three family members who have been missing since a winter storm hit last...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Arizona overwhelms Akron with 3s and dunks in 93-65 March Madness victory
# Summary: SEATTLE (AP) — Jaden Bradley, Trey Townsend and Caleb Love hit 3-pointers within the first two minutes, and No. 4 seed Arizona easily dismissed 13th-seeded Ak...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Arizona State star Cam Skattebo sued by former teammate over golf cart incident
# Summary: Arizona State star running back Cam Skattebo is being sued by a former teammate.
#
# Skattebo is on the receiving end of a civil complaint on behalf of his former ...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Adidas Arizona State Adizero Sl2 Team Colleg Gold 2 / Team Maroon 2
# Summary: The Adidas Arizona State Adizero Sl2 Team Colleg Gold 2 / Team Maroon 2 embodies the spirit and tradition of Arizona State University with its striking color sc...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Kansas State Wildcats take on the Arizona State Sun Devils in Big 12 Tournament
# Summary: Arizona State Sun Devils (13-18, 4-16 Big 12) vs. Kansas State Wildcats (15-16, 9-11 Big 12)
#
# Kansas City, Missouri; Tuesday, 7 p.m. EDT
#
# BETMGM SPORTSBOOK LINE...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: University of Arizona mining innovation engine aims to build skilled domestic workforce
# Summary: With the US on a mission to increase critical minerals production and decrease its reliance on foreign imports, an executive order signed by President Trump on ...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Storm dumps heavy snow on northern Arizona, gridlocking Interstate 40
# Summary: A winter storm has dumped heavy snow across northern Arizona, playing a major factor in a more than 15-mile backup on a major interstate
#
# Cars sit in traffic ba...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title

# Sentiment: 3
# --------------------------------------------------------------------------------
# Title: Intelsat to Supply Satcom Solution to County Sheriff’s Office in Arizona for Border Security
# Summary: Intelsat is supplying a multi-layer communication system (MLCS) to the Sheriff’s Office in Cochise County, Arizona to enable border security operations.
#
# The ...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: NHRA star Ron Capps' funny car explodes, crashes during Arizona Nationals
# Summary: National Hot Rod Association (NHRA) funny car driver Ron Capps was involved in a scary crash during the Arizona Nationals on Sunday.
#
# Capps’ vehicle came off ...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Missing Arizona yoga teacher Marcus Freiberger found dead after going on blind date
# Summary: A beloved Arizona yoga teacher who vanished after he set out for a would-be romantic meetup with a blind date last month has been found dead.
#
# The body of Marcu...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Texas Tech survives Baylor’s comeback attempt, will face Arizona in semifinal
# Summary: LUBBOCK, Texas (KCBD) - JT Toppin and Elijah Hawkins notched double-doubles as No. 2-seed Texas Tech beat No. 7-seed Baylor in the Phillip’s 66 Big 12 Champio...
# Sentiment: 3
# --------------------------------------------------------------------------------
# Title: Wednesday’s HotCopper Trends: Imugene scores FDA tick, Arizona kicks off share purchase plan | March 19, 2025
# Summary: Join our daily newsletter At The Bell to receive exclusive market insights
#
# The ASX has been trading flat at around 7,864 points.
#
# Financials has been the best ...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Arizona teacher allegedly exposed himself in front of class while peeing in can at desk, offered odd excuse: police
# Summary: A teacher in Arizona had the wrong stream of thought.
#
# Elementary school educator Curt Hinton allegedly exposed his penis in front of a class full of students t...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Whitestone REIT to Open The Picklr Cave Creek at Terravita Marketplace in North Scottsdale, Arizona
# Summary: World’s fastest-growing indoor pickleball operator supports the market’s active and health-conscious lifestyle while also complementing Terravita’s divers...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Taiwan’s president praises TSMC’s $165 billion pledge to build semiconductor foundries in Arizona as ‘best model’ to create ‘non-red’ supply chain
# Summary: Taiwan’s President William Lai Ching-te said that a Taiwanese semiconductor company's massive investment in Arizona is the “best model” for the island's e...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Arizona Rep. Raúl Grijalva dies of complications from cancer treatment at 77
# Summary: WASHINGTON (AP) — Democratic U.S. Rep. Raúl M. Grijalva of Arizona, who championed environmental protection during his 12 terms in Congress, died Thursday of...
# Sentiment: 1
# --------------------------------------------------------------------------------
# Title: Monday’s HotCopper Trends: Spartan and Ramelius merger, Arizona capital raise | March 17, 2025
# Summary: Join our daily newsletter At The Bell to receive exclusive market insights
#
# The ASX has been up 0.62% at 7,837 points, following Wall Street’s Friday lead.
#
# I...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Arizona State Card Show | Autograph signings, hundreds of dealer tables, sports memorabilia and more
# Summary: PHOENIX — Collect cards, and build memories at the Phoenix Convention Center this month! The founder of the Arizona State Card Show lays out what’s on deck ...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: Chris Ashby scores 22 to lead Queens University over Northern Arizona 85-78 in first round of CBI
# Summary: DAYTONA BEACH, Fla. (AP) — Chris Ashby scored 22 points to lead Queens University to an 85-78 victory over Northern Arizona in the first round of the CBI Tour...
# Sentiment: 4
# --------------------------------------------------------------------------------
# Title: Emergency room security guard shot and wounded in Arizona; man arrested
# Summary: SCOTTSDALE, Ariz. (AP) — A security guard at an Arizona hospital was shot and wounded over the weekend, and the man suspected in the attack was quickly disarm...
# Sentiment: 2
# --------------------------------------------------------------------------------
# Title: ‘Heavily loved’ Arizona yoga teacher vanishes after going to meet blind date
# Summary: A “handsome” and “heavily loved” Arizona yoga teacher has been missing for nearly a month after going to meet up with a blind date, according to concern...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title

# Sentiment: 3
# --------------------------------------------------------------------------------
# Title: Minnesota’s singing McDonald’s drive-thru star takes act to Arizona
# Summary: Daniel Marshall gained fans during COVID singing to customers at the McDonalds in Arden Hills, Minnesota.
#
# ARDEN HILLS, Minn. — Editor’s Note: This story or...
# Sentiment: 3
# --------------------------------------------------------------------------------
# Title: Duke gets No. 1 regional seed for March Madness, headlines East with Alabama, Wisconsin, Arizona
# Summary: Duke headlines the NCAA Tournament’s East Region as a No. 1 seed and will open the push for the program’s sixth national title with a short drive from campu...
# Sentiment: 5
# --------------------------------------------------------------------------------
# Title: NTSB Scrutinizes Landing Gear in Learjet Accident in Arizona
# Summary: Federal accident investigators are focusing on landing gear failure as a possible factor that led to the death of one person and injured three others when two b...
# Sentiment: 1
# --------------------------------------------------------------------------------
#
# Detected Topics:
#
# Topic 1:
# - Koa Peat, one of the highest-ranked uncommitted high school prospects in the country, has committed to Arizona. Peat chose Arizona over Arizona State, Baylor, H...
# - Image Credit Arizona Inn
#
# The historic Arizona Inn, located in Tucson, Arizona, is up for sale.
#
# The resort has been owned and operated by the family of its fou...
# - Posted in: Card Games, Games, Spin Master Games, Tabletop | Tagged: AriZona 99, AriZona Iced Tea
#
# Spin Master Releases New AriZona Iced Tea Party Game
#
# Spin Mas...
#
# Topic 2:
# - Featured
#
# Here are the Top 10 Italian restaurants in Arizona, based on public voting for the 2025 edition of Ranking Arizona, the state’s biggest and most com...
# - HATE IN ARIZONA: An arsonist allegedly set fire to the Khal Chasidim Jewish Community Center in Casa Grande, Arizona, causing extensive damage to the newly reno...
# - Arizona lawmakers have introduced a crucial bill that ensures parents are fully informed of their right to obtain vaccine exemptions for school attendance.
#
# HB ...
#
# Topic 3:
# - Rochester, Minn.-based Mayo Clinic is investing nearly $1.9 billion to expand its Phoenix campus, marking the health system's largest investment in the state.
#
# ...
# - Gambling content 21+. The New York Post may receive an affiliate commission if you sign up through our links. Read our editorial standards for more information....
# - SAN JUAN CAPISTRANO, Calif., March 03, 2025 (GLOBE NEWSWIRE) -- The Ensign Group, Inc. ( ENSG), the parent company of the EnsignTM group of companies, which inv...
#
# Topic 4:
# - Arizona State Sun Devils (13-16, 4-14 Big 12) at Arizona Wildcats (19-10, 13-6 Big 12)
#
# Tucson, Arizona; Tuesday, 11 p.m. EST
#
# BOTTOM LINE: Arizona State visits...
# - TUCSON, Ariz. (AP) — Henri Veesaar scored 22 points, Caleb Love added 21 and No. 24 Arizona pulled away for a 113-100 win over rival Arizona State on Tuesday ...
# - The No. 24 Arizona Wildcats look to clinch a top-four seed in next week's Big 12 Tournament as they host in-state rivals, the Arizona State Sun Devils on Tuesda...
#
# Topic 5:
# - Northern Colorado Bears (21-8, 13-3 Big Sky) at Northern Arizona Lumberjacks (16-13, 7-9 Big Sky)
#
# Flagstaff, Arizona; Saturday, 10 p.m. EST
#
# BOTTOM LINE: North...
# - Northern Colorado Bears (21-8, 13-3 Big Sky) at Northern Arizona Lumberjacks (16-13, 7-9 Big Sky)
#
# Flagstaff, Arizona; Saturday, 10 p.m. EST
#
# BETMGM SPORTSBOOK ...
# - The Queens Royals square off against the Northern Arizona Lumberjacks in the College Basketball Invitational
#
# By The Associated Press
#
# Northern Arizona Lumberja...

# %%
import sqlite3

def store_full_analyzed_articles(location_name, raw_articles, analyzed_articles, db_name="location_news_full.db"):
    conn = sqlite3.connect(db_name)  #  saves to your local directory
    c = conn.cursor()

    # Create table with extended fields
    c.execute('''
        CREATE TABLE IF NOT EXISTS news_analysis (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            location TEXT,
            title TEXT,
            description TEXT,
            snippet TEXT,
            url TEXT,
            image_url TEXT,
            language TEXT,
            published_at TEXT,
            source TEXT,
            categories TEXT,
            relevance_score REAL,
            summary TEXT,
            sentiment TEXT
        )
    ''')

    # Insert each article with enriched metadata
    for raw, analyzed in zip(raw_articles, analyzed_articles):
        c.execute('''
            INSERT INTO news_analysis (
                location, title, description, snippet, url, image_url, language,
                published_at, source, categories, relevance_score, summary, sentiment
            ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
        ''', (
            location_name,
            raw.get("title"),
            raw.get("description"),
            raw.get("snippet"),
            raw.get("url"),
            raw.get("image_url"),
            raw.get("language"),
            raw.get("published_at"),
            raw.get("source"),
            ", ".join(raw.get("categories", [])) if raw.get("categories") else None,
            raw.get("relevance_score"),
            analyzed.get("summary"),
            analyzed.get("sentiment")
        ))

    conn.commit()
    conn.close()
    return db_name

# %%
db_file_path = store_full_analyzed_articles("Arizona", arizona_articles, analyzed_articles)
print(f"Saved to: {db_file_path}")

import pandas as pd
df = pd.read_sql("SELECT * FROM news_analysis", sqlite3.connect("location_news_full.db"))
df
# Out:
# Saved to: location_news_full.db
#       id location                                              title  \
# 0      1  Arizona  Ranking Arizona: Top 10 Italian restaurants in...
# 1      2  Arizona  Arizona State faces No. 22 Arizona after Sanon...
# 2      3  Arizona                        Koa Peat Commits To Arizona
# 3      4  Arizona  Henri Veesaar scores 22 points, No. 24 Arizona...
# 4      5  Arizona  Arizona vs. Arizona State odds, prediction, ti...
# ..   ...      ...                                                ...
# 595  596  Arizona  USWNT star Sophia Wilson and husband, Arizona ...
# 596  597  Arizona  Judge to allow camera in Lori Vallow Daybell's...
# 597  598  Arizona  Minnesota’s singing McDonald’s drive-thru star...
# 598  599  Arizona  Duke gets No. 1 regional seed for March Madnes...
# 599  600  Arizona  NTSB Scrutinizes Landing Gear in Learjet Accid...
#
#                                            description  \
# 0    Here are the Top 10 Italian restaurants in Ari...
# 1              Breaking News, Sports, Manitoba, Canada
# 2         Koa Peat Commits To Arizona - RealGM Wiretap
# 3              Breaking News, Sports, Manitoba, Canada
# 4    SportsLine's model just revealed its college b...
# ..                                                 ...
# 595  A timetable for the forward's return to NWSL a...
# 596  Maricopa County Superior Court Judge Justin Be...
# 597  Daniel Marshall gained fans during COVID by si...
# 598            Breaking News, Sports, Manitoba, Canada
# 599  NTSB investigators are focusing on landing gea...
#
#                                                snippet  \
# 0    Featured\n\nHere are the Top 10 Italian restau...
# 1    Arizona State Sun Devils (13-16, 4-14 Big 12) ...
# 2    Koa Peat, one of the highest-ranked uncommitte...
# 3    TUCSON, Ariz. (AP) — Henri Veesaar scored 22 p...
# 4    The No. 24 Arizona Wildcats look to clinch a t...
# ..                                                 ...
# 595  U.S. women's national team striker and Portlan...
# 598   5 stars
# 599    1 star
#
# [600 rows x 14 columns]

# %%
# calculate state score

def compute_state_sentiment(analyzed_articles):
    scores = [article['sentiment'] for article in analyzed_articles]

    if not scores:
        return None, "No articles"

    avg = sum(scores) / len(scores)



    return round(avg, 2)

# %%
compute_state_sentiment(analyzed_articles)
# Out:
# 2.61

# %%
# Generalize it to all the states

# %%
import pandas as pd

# %%
depo_location=pd.read_csv('Regeneron_cleaned_triallocation.csv')
depo_location
# Out:
#             NCT ID                                              Title  \
# 0      NCT01507831  Long-term Safety and Tolerability of Alirocuma...
# 1      NCT01507831  Long-term Safety and Tolerability of Alirocuma...
# 2      NCT01507831  Long-term Safety and Tolerability of Alirocuma...
# 3      NCT01507831  Long-term Safety and Tolerability of Alirocuma...
# 4      NCT01507831  Long-term Safety and Tolerability of Alirocuma...
# ...            ...                                                ...
# 16378  NCT01773954  Repeated Eye Injections of Aflibercept for Tre...
# 16379  NCT05036733  Effects of Interleukin (IL)- 4R-alpha Inhibiti...
# 16380  NCT06439654  Atlantic Lipid Lowering Treatment Optimization...
# 16381  NCT06439654  Atlantic Lipid Lowering Treatment Optimization...
# 16382  NCT01724554  Impact of Intravitreal Aflibercept Injections ...
#
#                    Status                      Lead Sponsor  \
# 0               COMPLETED                            Sanofi
# 1               COMPLETED                            Sanofi
# 2               COMPLETED                            Sanofi
# 3               COMPLETED                            Sanofi
# 4               COMPLETED                            Sanofi
# ...                   ...                               ...
# 16378           COMPLETED                MidAtlantic Retina
# 16379           COMPLETED            University of Michigan
# 16380  NOT_YET_RECRUITING            Atlantic Health System
# 16381  NOT_YET_RECRUITING            Atlantic Health System
# 16382           COMPLETED  Ophthalmic Consultants of Boston
#
#                    Collaborators                                  Facility  \
# 0      Regeneron Pharmaceuticals        Investigational Site Number 840159
# 1      Regeneron Pharmaceuticals        Investigational Site Number 840028
# 2      Regeneron Pharmaceuticals        Investigational Site Number 840035
# 3      Regeneron Pharmaceuticals        Investigational Site Number 840052
# 4      Regeneron Pharmaceuticals        Investigational Site Number 840065
# ...                          ...                                       ...
# 16378  Regeneron Pharmaceuticals  Mid Atlantic Retina- Wills Eye Institute
# 16379  Regeneron Pharmaceuticals                    University of Michigan
# 16380  Regeneron Pharmaceuticals                    Atlantic Medical Group
# 16381  Regeneron Pharmaceuticals                    Atlantic Medical Group
# 16382  Regeneron Pharmaceuticals          Ophthalmic Consultants of Boston
#
#                State        Country Zip Code
# 0            Alabama  United States    35801
# 1            Arizona  United States    85295
# 2            Arizona  United States    85635
# 3            Arizona  United States    85282
# 4            Arizona  United States    85282
# ...              ...            ...      ...
# 16378   Pennsylvania  United States    19107
# 16379       Michigan  United States    48109
# 16380     New Jersey  United States     7066
# 16381     New Jersey  United States     7081
# 16382  Massachusetts  United States     2114
#
# [16383 rows x 9 columns]

# %%
depo_location

# %%
# Get a list of unique states from the 'State' column
unique_states = depo_location['State'].dropna().unique()
unique_states.sort()
unique_states.tolist()
len(unique_states)
# Out:
# 496

# %%
us_states = depo_location[depo_location['Country'] == 'United States']['State'].dropna().unique()
us_states.sort()
us_states.tolist()
len(us_states)
# Out:
# 49

# %%
api_key='EpCH2HzrFgqr9fEUdYubTdYp0BIRXjE4cnHcVlnO'

# %%
# limited version

def fetch_location_news(api_key, location="Arizona", days_back=30, max_pages=2):
    BASE_URL = "https://api.thenewsapi.com/v1/news/all"
    start_date = (datetime.utcnow() - timedelta(days=days_back)).strftime("%Y-%m-%d")
    all_articles = []
    page = 1

    while page <= max_pages:
        params = {
            "api_token": api_key,
            "language": "en",
            "search": location,
            "limit": 100,
            "page": page,
            "published_after": start_date
        }

        response = requests.get(BASE_URL, params=params)
        if response.status_code != 200:
            print(f"[{location}] Page {page} - Error: {response.text}")
            break

        data = response.json().get("data", [])
        if not data:
            break

        filtered_data = [
            article for article in data
            if article.get("relevance_score") and article["relevance_score"] > 5
        ]

        all_articles.extend(filtered_data)
        page += 1

    return all_articles

# %%
def analyze_all_states(api_key, db_name="location_news_full.db"):
    sentiment_scores = {}

    for state in us_states:
        print(f"\nProcessing: {state}")
        raw_articles = fetch_location_news(api_key, state)

        if not raw_articles:
            print(f"No articles found for {state}")
            sentiment_scores[state] = None
            continue

        analyzed_articles, _ = analyze_news(raw_articles)

        # Store into SQLite
        store_full_analyzed_articles(state, raw_articles, analyzed_articles, db_name)

        # Compute sentiment
        score = compute_state_sentiment(analyzed_articles)
        sentiment_scores[state] = score
        print(f"{state} sentiment score: {score}")

    return sentiment_scores

# %%
sentiment_scores= analyze_all_states(api_key, db_name="location_news_full.db")
# Out:
# 📰 Processing: Alabama
# ✅ Alabama sentiment score: 3.83
#
# 📰 Processing: Arizona
# ✅ Arizona sentiment score: 2.5
#
# 📰 Processing: Arkansas
# ✅ Arkansas sentiment score: 3.17
#
# 📰 Processing: California
# ✅ California sentiment score: 2.67
#
# 📰 Processing: Colorado
# ✅ Colorado sentiment score: 2.83
#
# 📰 Processing: Connecticut
# ✅ Connecticut sentiment score: 1.67
#
# 📰 Processing: Delaware
# ✅ Delaware sentiment score: 2.67
#
# 📰 Processing: District of Columbia
# ✅ District of Columbia sentiment score: 1.5
#
# 📰 Processing: Florida
# ✅ Florida sentiment score: 2.67
#
# 📰 Processing: Georgia
# ✅ Georgia sentiment score: 2.67
#
# 📰 Processing: Hawaii
# ✅ Hawaii sentiment score: 3.0
#
# 📰 Processing: Idaho
# ✅ Idaho sentiment score: 2.0
#
# 📰 Processing: Illinois
# ✅ Illinois sentiment score: 3.17
#
# 📰 Processing: Indiana
# ✅ Indiana sentiment score: 3.17
#
# 📰 Processing: Iowa
# ✅ Iowa sentiment score: 2.67
#
# 📰 Processing: Kansas
# ✅ Kansas sentiment score: 3.67
#
# 📰 Processing: Kentucky
# ✅ Kentucky sentiment score: 2.0
#
# 📰 Processing: Louisiana
# ✅ Louisiana sentiment score: 2.67
#
# 📰 Processing: Maine
# ✅ Maine sentiment score: 2.5
#
# 📰 Processing: Maryland
# ✅ Maryland sentiment score: 3.33
#
# 📰 Processing: Massachusetts
# ✅ Massachusetts sentiment score: 1.83
#
# 📰 Processing: Michigan
# ✅ Michigan sentiment score: 1.67
#
# 📰 Processing: Minnesota
# ✅ Minnesota sentiment score: 2.5
#
# 📰 Processing: Mississippi
# ✅ Mississippi sentiment score: 2.5
#
# 📰 Processing: Missouri
# ✅ Missouri sentiment score: 3.17
#
# 📰 Processing: Montana
# ✅ Montana sentiment score: 2.67
#
# 📰 Processing: Nebraska
# ✅ Nebraska sentiment score: 2.5
#
# 📰 Processing: Nevada
# ✅ Nevada sentiment score: 4.67
#
# 📰 Processing: New Hampshire
# ✅ New Hampshire sentiment score: 2.17
#
# 📰 Processing: New Jersey
# ✅ New Jersey sentiment score: 3.0
#
# 📰 Processing: New Mexico
# ✅ New Mexico sentiment score: 3.0
#
# 📰 Processing: New York
# ✅ New York sentiment score: 3.5
#
# 📰 Processing: North Carolina
# ✅ North Carolina sentiment score: 1.83
#
# 📰 Processing: North Dakota
# ✅ North Dakota sentiment score: 1.67
#
# 📰 Processing: Ohio
# ✅ Ohio sentiment score: 3.83
#
# 📰 Processing: Oklahoma
# ✅ Oklahoma sentiment score: 3.33
#
# 📰 Processing: Oregon
# ✅ Oregon sentiment score: 3.67
#
# 📰 Processing: Pennsylvania
# ✅ Pennsylvania sentiment score: 2.67
#
# 📰 Processing: Rhode Island
# ✅ Rhode Island sentiment score: 3.5
#
# 📰 Processing: South Carolina
# ✅ South Carolina sentiment score: 2.17
#
# 📰 Processing: South Dakota
# ✅ South Dakota sentiment score: 1.0
#
# 📰 Processing: Tennessee
# ✅ Tennessee sentiment score: 3.0
#
# 📰 Processing: Texas
# ✅ Texas sentiment score: 3.83
#
# 📰 Processing: Utah
# ✅ Utah sentiment score: 3.0
#
# 📰 Processing: Vermont
# ✅ Vermont sentiment score: 4.33
#
# 📰 Processing: Virginia
# ✅ Virginia sentiment score: 2.5
#
# 📰 Processing: Washington
# ✅ Washington sentiment score: 3.17
#
# 📰 Processing: West Virginia
# ✅ West Virginia sentiment score: 2.5
#
# 📰 Processing: Wisconsin
# ✅ Wisconsin sentiment score: 4.0

# %%
sentiment_scores
# Out:
# {'Alabama': 3.83,
#  'Arizona': 2.5,
#  'Arkansas': 3.17,
#  'California': 2.67,
#  'Colorado': 2.83,
#  'Connecticut': 1.67,
#  'Delaware': 2.67,
#  'District of Columbia': 1.5,
#  'Florida': 2.67,
#  'Georgia': 2.67,
#  'Hawaii': 3.0,
#  'Idaho': 2.0,
#  'Illinois': 3.17,
#  'Indiana': 3.17,
#  'Iowa': 2.67,
#  'Kansas': 3.67,
#  'Kentucky': 2.0,
#  'Louisiana': 2.67,
#  'Maine': 2.5,
#  'Maryland': 3.33,
#  'Massachusetts': 1.83,
#  'Michigan': 1.67,
#  'Minnesota': 2.5,
#  'Mississippi': 2.5,
#  'Missouri': 3.17,
#  'Montana': 2.67,
#  'Nebraska': 2.5,
#  'Nevada': 4.67,
#  'New Hampshire': 2.17,
#  'New Jersey': 3.0,
#  'New Mexico': 3.0,
#  'New York': 3.5,
#  'North Carolina': 1.83,
#  'North Dakota': 1.67,
#  'Ohio': 3.83,
#  'Oklahoma': 3.33,
#  'Oregon': 3.67,
#  'Pennsylvania': 2.67,
#  'Rhode Island': 3.5,
#  'South Carolina': 2.17,
#  'South Dakota': 1.0,
#  'Tennessee': 3.0,
#  'Texas': 3.83,
#  'Utah': 3.0,
#  'Vermont': 4.33,
#  'Virginia': 2.5,
#  'Washington': 3.17,
#  'West Virginia': 2.5,
#  'Wisconsin': 4.0}

# %%
import csv
sentiment_data = [{"State": state, "Sentiment Score": score} for state, score in sentiment_scores.items()]
csv_filename = "/mnt/data/state_sentiment_scores.csv"

with open("state_sentiment_scores.csv", mode="w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=["State", "Sentiment Score"])
    writer.writeheader()
    writer.writerows(sentiment_data)

print("✅ Saved to state_sentiment_scores.csv")
# Out:
# ✅ Saved to state_sentiment_scores.csv

# %%
db_file_path = store_full_analyzed_articles("Arizona", arizona_articles, analyzed_articles)
print(f"Saved to: {db_file_path}")

import pandas as pd
df = pd.read_sql("SELECT * FROM news_analysis", sqlite3.connect("location_news_full.db"))
df
# Out:
# Saved to: location_news_full.db
#         id location                                              title  \
# 0        1  Arizona  Ranking Arizona: Top 10 Italian restaurants in...
# 1        2  Arizona  Arizona State faces No. 22 Arizona after Sanon...
# 2        3  Arizona                        Koa Peat Commits To Arizona
# 3        4  Arizona  Henri Veesaar scores 22 points, No. 24 Arizona...
# 4        5  Arizona  Arizona vs. Arizona State odds, prediction, ti...
# ...    ...      ...                                                ...
# 1195  1196  Arizona  USWNT star Sophia Wilson and husband, Arizona ...
# 1196  1197  Arizona  Judge to allow camera in Lori Vallow Daybell's...
# 1197  1198  Arizona  Minnesota’s singing McDonald’s drive-thru star...
# 1198  1199  Arizona  Duke gets No. 1 regional seed for March Madnes...
# 1199  1200  Arizona  NTSB Scrutinizes Landing Gear in Learjet Accid...
#
#                                             description  \
# 0     Here are the Top 10 Italian restaurants in Ari...
# 1               Breaking News, Sports, Manitoba, Canada
# 2          Koa Peat Commits To Arizona - RealGM Wiretap
# 3               Breaking News, Sports, Manitoba, Canada
# 4     SportsLine's model just revealed its college b...
# ...                                                 ...
# 1195  A timetable for the forward's return to NWSL a...
# 1196  Maricopa County Superior Court Judge Justin Be...
# 1197  Daniel Marshall gained fans during COVID by si...
# 1198            Breaking News, Sports, Manitoba, Canada
# 1199  NTSB investigators are focusing on landing gea...
#
#                                                 snippet  \
# 0     Featured\n\nHere are the Top 10 Italian restau...
# 1     Arizona State Sun Devils (13-16, 4-14 Big 12) ...
# 2     Koa Peat, one of the highest-ranked uncommitte...
# 3     TUCSON, Ariz. (AP) — Henri Veesaar scored 22 p...
# 4     The No. 24 Arizona Wildcats look to clinch a t...
# ...                                                 ...
# 1195  U.S. women's national team striker and Portlan...
# 1196  Estimated read time: 2-3 minutes\n\nPHOENIX — ...
# 1197  Daniel Marshall gained fans during COVID singi...
# 1198  Duke headlines the NCAA Tournament’s East Regi...
# 1199  Federal accident investigators are focusing on...
#
#                                                     url  \
# 0     https://azbigmedia.com/lifestyle/ranking-arizo...
# 1     https://www.winnipegfreepress.com/uncategorize...
# 2     https://basketball.realgm.com/wiretap/279797/K...
# 3     https://www.winnipegfreepress.com/uncategorize...
# 4     https://www.cbssports.com/college-basketball/n...
# ...                                                 ...
# 1195  https://www.cbssports.com/soccer/news/uswnt-st...
# 1196  https://www.ksl.com/article/51273085/judge-to-...
# 1197  https://www.kare11.com/article/news/local/land...
# 1198  https://www.winnipegfreepress.com/uncategorize...
# 1199  https://www.flyingmag.com/ntsb-scrutinizes-lan...
#
#                                               image_url language  \
# 0     https://azbigmedia.com/wp-content/uploads/2025...       en
# 1     https://www.winnipegfreepress.com/wp-content/u...       en
# 2     https://basketball.realgm.com/images/nba/4.2/w...       en
# 3     https://www.winnipegfreepress.com/wp-content/u...       en
# 4     https://sportshub.cbsistatic.com/i/r/2025/02/0...       en
# ...                                                 ...      ...
# 1195  https://sportshub.cbsistatic.com/i/r/2025/03/0...       en
# 1196  https://img.ksl.com/slc/3046/304618/30461899.j...       en
# 1197  https://media.kare11.com/assets/KARE/images/df...       en
# 1198  https://www.winnipegfreepress.com/wp-content/u...       en
# 1199  https://www.flyingmag.com/uploads/2025/03/NTSB...       en
#
#                      published_at                   source categories  \
# 0     2025-03-22T12:34:16.000000Z  agriculture.einnews.com       food
# 1     2025-03-03T08:45:47.000000Z    winnipegfreepress.com    general
# 2     2025-03-27T18:51:35.000000Z    basketball.realgm.com     sports
# 3     2025-03-05T06:36:09.000000Z    winnipegfreepress.com       None
# 4     2025-03-04T15:30:12.000000Z            cbssports.com     sports
# ...                           ...                      ...        ...
# 1195  2025-03-05T17:48:00.000000Z            cbssports.com     sports
# 1196  2025-03-12T00:18:00.000000Z                  ksl.com       None
# 1197  2025-03-18T02:00:00.000000Z               kare11.com    general
# 1198  2025-03-16T22:36:23.000000Z    winnipegfreepress.com    general
# 1199  2025-03-03T17:09:33.000000Z            flyingmag.com       tech
#
#       relevance_score                                            summary  \
# 0           23.638367  Featured\n\nHere are the Top 10 Italian restau...
# 1           23.514057  Arizona State Sun Devils (13-16, 4-14 Big 12) ...
# 2           22.228500  Koa Peat, one of the highest-ranked uncommitte...
# 3           22.208956  TUCSON, Ariz. (AP) — Henri Veesaar scored 22 p...
# 4           22.017650  The No. 24 Arizona Wildcats look to clinch a t...
# ...               ...                                                ...
# 1195        13.868391  U.S. women's national team striker and Portlan...
# 1196        13.868391  Estimated read time: 2-3 minutes\n\nPHOENIX — ...
# 1197        13.856299  Daniel Marshall gained fans during COVID singi...
# 1198        13.810841  Duke headlines the NCAA Tournament’s East Regi...
# 1199        13.770459  Federal accident investigators are focusing on...
#
#      sentiment
# 0      5 stars
# 1      3 stars
# 2       1 star
# 3       1 star
# 4      4 stars
# ...        ...
# 1195         4
# 1196         3
# 1197         3
# 1198         5
# 1199         1
#
# [1200 rows x 14 columns]

# %%
df = pd.read_csv("active_sites_filtered.csv")
countries = df["Country"].dropna().unique().tolist()

# %%
len(countries)
# Out:
# 25
